# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(
    { "figure.figsize": (6, 4) },
    style='ticks',
    color_codes=True,
    font_scale=0.8
)
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')

import statsmodels.api as sm

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from category_encoders import TargetEncoder
import category_encoders as ce
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sklearn.metrics import PredictionErrorDisplay
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE, SelectKBest, f_regression
from sklearn.feature_selection import SequentialFeatureSelector
import xgboost as xgb
import lightgbm as lgb


from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold

from sklearn.inspection import PartialDependenceDisplay

# For reproducibility
random_state = 42

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from time import time

# %% [markdown]
# ### USING SYSTEM GPU

# %%
import torch

def test_pytorch_gpu():
    print("PyTorch version:", torch.__version__)
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print("CUDA is available. Using GPU.")
    else:
        device = torch.device("cpu")
        print("CUDA is not available. Using CPU.")
    
    # Tensor operation to test GPU
    x = torch.randn((2, 2), device=device)
    y = torch.randn((2, 2), device=device)
    z = x + y
    print("x + y on device:", z, "\nDevice:", z.device)
    print("Done.")

if __name__ == "__main__":
    test_pytorch_gpu()
# Out:
# PyTorch version: 2.6.0+cu118
# CUDA is available. Using GPU.
# x + y on device: tensor([[ 1.6232, -0.4824],
#         [-1.2454,  1.0280]], device='cuda:0')
# Device: cuda:0
# Done.

# %%
car_auto = pd.read_csv('adverts.csv')

# %% [markdown]
# ##  1. Data Description and Pre-Processing

# %%
car_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402005 entries, 0 to 402004
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   public_reference       402005 non-null  int64
#  1   mileage                401878 non-null  float64
#  2   reg_code               370148 non-null  object
#  3   standard_colour        396627 non-null  object
#  4   standard_make          402005 non-null  object
#  5   standard_model         402005 non-null  object
#  6   vehicle_condition      402005 non-null  object
#  7   year_of_registration   368694 non-null  float64
#  8   price                  402005 non-null  int64
#  9   body_type              401168 non-null  object
#  10  crossover_car_and_van  402005 non-null  bool
#  11  fuel_type              401404 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 34.1+ MB

# %%
car_auto.head(7)
# Out:
#    public_reference   mileage reg_code standard_colour standard_make  \
# 0   202006039777689       0.0      NaN            Grey         Volvo
# 1   202007020778260  108230.0       61            Blue        Jaguar
# 2   202007020778474    7800.0       17            Grey         SKODA
# 3   202007080986776   45000.0       16           Brown      Vauxhall
# 4   202007161321269   64000.0       64            Grey    Land Rover
# 5   202009304412074   16000.0       17            Blue          Audi
# 6   202007080998445   24075.0       17             Red      Vauxhall
#
#       standard_model vehicle_condition  year_of_registration  price  \
# 0               XC90               NEW                   NaN  73970
# 1                 XF              USED                2011.0   7000
# 2               Yeti              USED                2017.0  14000
# 3              Mokka              USED                2016.0   7995
# 4  Range Rover Sport              USED                2015.0  26995
# ...

# %%
car_auto.describe(include='all')
# Out:
#         public_reference        mileage reg_code standard_colour  \
# count       4.020050e+05  401878.000000   370148          396627
# unique               NaN            NaN       72              22
# top                  NaN            NaN       17           Black
# freq                 NaN            NaN    36738           86287
# mean        2.020071e+14   37743.595656      NaN             NaN
# std         1.691662e+10   34831.724018      NaN             NaN
# min         2.013072e+14       0.000000      NaN             NaN
# 25%         2.020090e+14   10481.000000      NaN             NaN
# 50%         2.020093e+14   28629.500000      NaN             NaN
# 75%         2.020102e+14   56875.750000      NaN             NaN
# max         2.020110e+14  999999.000000      NaN             NaN
#
#        standard_make standard_model vehicle_condition  year_of_registration  \
# count         402005         402005            402005         368694.000000
# ...

# %%
car_auto.isna().sum()
# Out:
# public_reference             0
# mileage                    127
# reg_code                 31857
# standard_colour           5378
# standard_make                0
# standard_model               0
# vehicle_condition            0
# year_of_registration     33311
# price                        0
# body_type                  837
# crossover_car_and_van        0
# fuel_type                  601
# dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.heatmap(car_auto.isna(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("Missing - value map (yellow = missing)")
plt.xlabel("Features")
plt.show()

# %%
missing = car_auto.isna().sum().sort_values(ascending=False)
plt.figure(figsize=(6,4))
sns.barplot(x=missing.values, y=missing.index, palette="mako")
plt.title("Count of missing per feature")
plt.xlabel("Number missing")
plt.show()

# %% [markdown]
# ### 1.2 PREPROCESSING PIPELINE

# %% [markdown]
# Creating a pipeline to identify and handle missing values, outliers, noise; encode categorical variables; scale features; partition data into training, validation and test sets.

# %% [markdown]
# 1. Cap Outliers (Mileage) with quantile-based boundaries.
#
# 2. Impute Mileage by (standard_make, vehicle_condition) group median.
#
# 3. Fix Year
#
#  For rows with year_of_registration < 1933, fill from reg_code group median.
#
# If vehicle_condition == 'NEW' and missing, set to 2021.
#
# Otherwise, brand-based median fallback, then global median.
#
# 4. Parse public_reference into (year_listed, month_listed, day_listed).
#
# 5. Impute Standard Colour by (standard_make, vehicle_condition) mode.
#
# 6. Impute Body Type & Fuel Type by standard_make mode.
#
# 7. Map categories in body_type, fuel_type, and standard_colour to consolidated groups.
#
# 8. Drop reg_code (after it’s been used in the year fix).

# %%
# ─────────────────────────────────────────────────────────────────
# A) CapOutliers
# ─────────────────────────────────────────────────────────────────
class CapOutliers(BaseEstimator, TransformerMixin):
    """
    Caps outliers in a specified numeric column based on quantiles.
    """
    def __init__(self, column, lower_quantile=0.05, upper_quantile=0.95, factor=1.5):
        self.column = column
        self.lower_quantile = lower_quantile
        self.upper_quantile = upper_quantile
        self.factor = factor
        self.lower_bound_ = None
        self.upper_bound_ = None

    def fit(self, X, y=None):
        Q1 = X[self.column].quantile(self.lower_quantile)
        Q3 = X[self.column].quantile(self.upper_quantile)
        IQR = Q3 - Q1
        self.lower_bound_ = Q1 - self.factor * IQR
        self.upper_bound_ = Q3 + self.factor * IQR
        return self

    def transform(self, X):
        X = X.copy()
        X[self.column] = X[self.column].clip(lower=self.lower_bound_, upper=self.upper_bound_)
        return X

# ─────────────────────────────────────────────────────────────────
# B) GroupMedianImputerMileage
# ─────────────────────────────────────────────────────────────────
class GroupMedianImputerMileage(BaseEstimator, TransformerMixin):
    """
    Replace missing values in 'mileage' with the median mileage grouped by
    ('standard_make', 'vehicle_condition'). Then fallback to global median.
    """
    def __init__(self):
        self.group_medians_ = None
        self.global_median_ = None

    def fit(self, X, y=None):
        X_temp = X.copy()
        self.group_medians_ = X_temp.groupby(
            ['standard_make', 'vehicle_condition']
        )['mileage'].median()
        self.global_median_ = X_temp['mileage'].median()
        return self

    def transform(self, X):
        X = X.copy()

        def fill_mileage(row):
            if pd.isna(row['mileage']):
                return self.group_medians_.get(
                    (row['standard_make'], row['vehicle_condition']),
                    self.global_median_  # fallback
                )
            return row['mileage']

        X['mileage'] = X.apply(fill_mileage, axis=1)
        return X

# ─────────────────────────────────────────────────────────────────
# C) YearRegistrationFixer
#    Uses 'reg_code' for out-of-range years, then drops 'reg_code' later
# ─────────────────────────────────────────────────────────────────
class YearRegistrationFixer(BaseEstimator, TransformerMixin):
    """
    - For year_of_registration < 1933 => fill from reg_code median if available
    - If vehicle_condition == NEW and missing => 2021
    - Else fill missing with brand-based median => global fallback
    """
    def __init__(self):
        self.regcode_medians_ = None
        self.brand_medians_ = None
        self.global_median_ = None

    def fit(self, X, y=None):
        X_temp = X.copy()

        # 1) regcode-based median for out-of-range
        if 'reg_code' in X_temp.columns:
            self.regcode_medians_ = X_temp.groupby('reg_code')['year_of_registration'].median()

        # 2) brand-based median for missing
        self.brand_medians_ = X_temp.groupby('standard_make')['year_of_registration'].median()
        self.global_median_ = X_temp['year_of_registration'].median()

        return self

    def transform(self, X):
        X = X.copy()

        def fix_out_of_range(row):
            y = row['year_of_registration']
            if pd.notna(y) and y < 1933:
                # Use regcode median if available
                if self.regcode_medians_ is not None:
                    return self.regcode_medians_.get(row['reg_code'], y)
            return y

        X['year_of_registration'] = X.apply(fix_out_of_range, axis=1)

        # Next: vehicle_condition == NEW & missing => 2021
        mask_new_and_nan = (X['vehicle_condition'] == 'NEW') & (X['year_of_registration'].isnull())
        X.loc[mask_new_and_nan, 'year_of_registration'] = 2021

        # Then fill remaining missing with brand median => fallback global
        def fill_brand_median(row):
            y = row['year_of_registration']
            if pd.isna(y):
                return self.brand_medians_.get(row['standard_make'], np.nan)
            return y

        X['year_of_registration'] = X.apply(fill_brand_median, axis=1)
        X['year_of_registration'] = X['year_of_registration'].fillna(self.global_median_)

        # Convert to int
        X['year_of_registration'] = X['year_of_registration'].astype(int, errors='ignore')

        return X

# ─────────────────────────────────────────────────────────────────
# D) ParsePublicReference
# ─────────────────────────────────────────────────────────────────
class ParsePublicReference(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()
        X['public_reference'] = X['public_reference'].astype(str)

        X['year_listed'] = X['public_reference'].str[:4].astype(int)
        X['month_listed'] = X['public_reference'].str[4:6].astype(int)
        X['day_listed'] = X['public_reference'].str[6:8].astype(int)

        # We'll drop public_reference in a separate step if we want
        return X

# ─────────────────────────────────────────────────────────────────
# E) StandardColourImputer
# ─────────────────────────────────────────────────────────────────
class StandardColourImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()

        def impute_with_mode(group):
            mode_val = group['standard_colour'].mode()
            if not mode_val.empty:
                return group['standard_colour'].fillna(mode_val[0])
            else:
                return group['standard_colour'].fillna('Unknown')

        # Group by (make, condition) for color
        X['standard_colour'] = (
            X.groupby(['standard_make', 'vehicle_condition'], group_keys=False)
             .apply(impute_with_mode)
        )
        # Final fallback
        X['standard_colour'] = X['standard_colour'].fillna('Unknown')
        return X

# ─────────────────────────────────────────────────────────────────
# F) BodyFuelImputer
# ─────────────────────────────────────────────────────────────────
class BodyFuelImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()

        # Body type by standard_make
        def fill_body_mode(group):
            mode_val = group['body_type'].mode()
            return group['body_type'].fillna(mode_val[0] if not mode_val.empty else 'unknown')

        X['body_type'] = (
            X.groupby('standard_make', group_keys=False)
             .apply(fill_body_mode)
        )

        # Fuel type by standard_make
        def fill_fuel_mode(group):
            mode_val = group['fuel_type'].mode()
            return group['fuel_type'].fillna(mode_val[0] if not mode_val.empty else 'Unknown')

        X['fuel_type'] = (
            X.groupby('standard_make', group_keys=False)
             .apply(fill_fuel_mode)
        )

        return X

# ─────────────────────────────────────────────────────────────────
# G) MapBodyTypeFuelColour
# ─────────────────────────────────────────────────────────────────
class MapBodyTypeFuelColour(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.body_type_mapping = {
            'Hatchback': 'Hatchback',
            'SUV': 'SUV',
            'Saloon': 'Saloon',
            'Estate': 'Estate',
            'Coupe': 'Coupe',
            'Convertible': 'Convertible',
            'MPV': 'MPV',
            'Pickup': 'Utility Vehicles',
            'Combi Van': 'Utility Vehicles',
            'Panel Van': 'Utility Vehicles',
            'Window Van': 'Utility Vehicles',
            'Camper': 'Utility Vehicles',
            'Limousine': 'Luxury/Passenger Vehicles',
            'Minibus': 'Luxury/Passenger Vehicles',
            'Chassis Cab': 'Utility Vehicles',
            'Car Derived Van': 'Utility Vehicles',
            'unknown': 'Utility Vehicles'
        }

        self.fuel_type_mapping = {
            'Petrol': 'Petrol',
            'Diesel': 'Diesel',
            'Electric': 'Electric',
            'Petrol Hybrid': 'Hybrid',
            'Diesel Hybrid': 'Hybrid',
            'Petrol Plug-in Hybrid': 'Hybrid',
            'Diesel Plug-in Hybrid': 'Hybrid',
            'Natural Gas': 'Bi/Gas',
            'Bi Fuel': 'Bi/Gas'
        }

        self.color_mapping = {
            'Bronze': 'Metallic',
            'Gold': 'Metallic',
            'Beige': 'Metallic',
            'Pink': 'Red/Purple',
            'Purple': 'Red/Purple',
            'Magenta': 'Red/Purple',
            'Burgundy': 'Red/Purple',
            'Multicolour': 'Custom',
            'Turquoise': 'Custom',
            'Yellow': 'Yellow',
            'Brown': 'Brown',
            'Navy': 'Blue',
            'Maroon': 'Red/Purple',
            'Unknown': 'Unknown',
            'Indigo': 'Blue'
        }

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()

        # Body types
        X['body_type'] = X['body_type'].map(self.body_type_mapping).fillna('Utility Vehicles')

        # Fuel
        X['fuel_type'] = X['fuel_type'].map(self.fuel_type_mapping).fillna('Unknown')

        # Colour
        X['standard_colour'] = X['standard_colour'].replace(self.color_mapping)

        return X

# ─────────────────────────────────────────────────────────────────
# H) DropColumns
#    We'll drop 'public_reference' and 'reg_code' (the latter after it's used)
# ─────────────────────────────────────────────────────────────────
class DropColumns(BaseEstimator, TransformerMixin):
    def __init__(self, cols_to_drop):
        self.cols_to_drop = cols_to_drop

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()
        X.drop(columns=self.cols_to_drop, inplace=True, errors='ignore')
        return X

# %%
def create_cleaning_pipeline():
    """
    Creates a pipeline that:
      1) Caps outliers in 'mileage'
      2) Imputes 'mileage' by (make, condition) median
      3) Fixes 'year_of_registration' using reg_code for <1933, then brand-based median
      4) Parses 'public_reference' => year_listed, month_listed, day_listed
      5) Imputes standard_colour by (make, condition) mode
      6) Imputes body_type, fuel_type by make mode
      7) Maps categories for body_type, fuel_type, standard_colour
      8) Drops 'reg_code' and 'public_reference'
    """
    return Pipeline([
        ("cap_outliers", CapOutliers(column="mileage", lower_quantile=0.05, upper_quantile=0.95)),
        ("impute_mileage", GroupMedianImputerMileage()),
        ("fix_year", YearRegistrationFixer()),
        ("parse_pubref", ParsePublicReference()),
        ("impute_colour", StandardColourImputer()),
        ("impute_bodyfuel", BodyFuelImputer()),
        ("map_bfc", MapBodyTypeFuelColour()),
        # Finally drop columns we don't need in the final dataset:
        ("drop_unused", DropColumns(cols_to_drop=["reg_code", "public_reference"]))
    ])

# %%
# Implementing the pipeline
pipeline = create_cleaning_pipeline()

# Fit-transform
car_auto_cl = pipeline.fit_transform(car_auto)

print("Shape after cleaning:", car_auto_cl.shape)
print(car_auto_cl.info())
car_auto_cl.head(10)
# Out:
# Shape after cleaning: (402005, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402005 entries, 0 to 402004
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   mileage                402005 non-null  float64
#  1   standard_colour        402005 non-null  object
#  2   standard_make          402005 non-null  object
#  3   standard_model         402005 non-null  object
#  4   vehicle_condition      402005 non-null  object
#  5   year_of_registration   402005 non-null  int32
#  6   price                  402005 non-null  int64
#  7   body_type              402005 non-null  object
#  8   crossover_car_and_van  402005 non-null  bool
#  9   fuel_type              402005 non-null  object
#  10  year_listed            402005 non-null  int32
#  11  month_listed           402005 non-null  int32
#  12  day_listed             402005 non-null  int32
# ...

# %%
create_cleaning_pipeline()
# Out:
# Pipeline(steps=[('cap_outliers', CapOutliers(column='mileage')),
#                 ('impute_mileage', GroupMedianImputerMileage()),
#                 ('fix_year', YearRegistrationFixer()),
#                 ('parse_pubref', ParsePublicReference()),
#                 ('impute_colour', StandardColourImputer()),
#                 ('impute_bodyfuel', BodyFuelImputer()),
#                 ('map_bfc', MapBodyTypeFuelColour()),
#                 ('drop_unused',
#                  DropColumns(cols_to_drop=['reg_code', 'public_reference']))])

# %%
fig, axes = plt.subplots(1,2, figsize=(12,4), sharey=True)
sns.heatmap(car_auto.isna(), cbar=False, yticklabels=False, cmap="viridis", ax=axes[0])
axes[0].set_title("Before Cleaning")
sns.heatmap(car_auto_cl.isna(), cbar=False, yticklabels=False, cmap="viridis", ax=axes[1])
axes[1].set_title("After Imputation")
plt.suptitle("Missingness Before & After")
plt.show()

# %% [markdown]
# #### Saving the file

# %%
car_auto_cl.to_csv('adverts_cl.csv', index=False)

# %% [markdown]
# ### Secondary Pipeline for feature engineering and transformation

# %% [markdown]
# multi-step workflow that creates additional features, handles categorical encodings (including target encoding for high-cardinality columns), applies log transforms, and then partitions the data into train/validation/test sets without data leakage

# %%
# --- Custom Transformer for Label Encoding 'vehicle_condition'
class VehicleConditionLabelEncoder(BaseEstimator, TransformerMixin):
    """Encodes 'vehicle_condition' using LabelEncoder."""
    def __init__(self):
        self.le_ = LabelEncoder()
    
    def fit(self, X, y=None):
        self.le_.fit(X['vehicle_condition'].astype(str))
        return self
    
    def transform(self, X):
        X = X.copy()
        X['vehicle_condition'] = self.le_.transform(X['vehicle_condition'].astype(str))
        return X

# --- Feature Engineering Transformer
class FeatureEngineer(BaseEstimator, TransformerMixin):
    """
    Creates meaningful features from raw car data:
    - vehicle_age = year_listed - year_of_registration (clipped to a minimum of 0)
    - mileage_per_year = mileage / (vehicle_age + epsilon)
    - mileage_age_interaction = mileage * vehicle_age
    - listing_month_day = month_listed * 100 + day_listed
    - standard_make_model = standard_make + "_" + standard_model
    - is_luxury_brand = binary indicator for luxury brands
    Then drops raw string/date columns no longer needed.
    """
    def __init__(self, luxury_brands=None, drop_vehicle_age=False):
        # Ensure the luxury brands list is all lowercase.
        self.luxury_brands = luxury_brands or [
            'mercedes-benz', 'bmw', 'audi', 'lexus', 'porsche', 
            'jaguar', 'land rover', 'bentley', 'maserati', 'ferrari', 'lamborghini'
        ]
        self.drop_vehicle_age = drop_vehicle_age
        
    def fit(self, X, y=None):
        self.input_columns_ = X.columns.tolist()
        return self
        
    def transform(self, X):
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X, columns=self.input_columns_)
        X = X.copy()
        
        # 1) Vehicle age computation.
        X['vehicle_age'] = X['year_listed'] - X['year_of_registration']
        X['vehicle_age'] = X['vehicle_age'].clip(lower=0)
        
        # 2) Mileage per year.
        X['mileage_per_year'] = X['mileage'] / (X['vehicle_age'] + 0.001)
        
        # 3) Mileage-age interaction.
        X['mileage_age_interaction'] = X['mileage'] * X['vehicle_age']
        
        # 4) Listing month_day.
        X['listing_month_day'] = X['month_listed'] * 100 + X['day_listed']
        
        # 5) Standard make_model.
        X['standard_make_model'] = X['standard_make'] + "_" + X['standard_model']
        
        # 6) Luxury brand indicator.
        X['is_luxury_brand'] = X['standard_make'].str.lower().isin(self.luxury_brands).astype(int)
        
        # Optionally drop 'vehicle_age'
        if self.drop_vehicle_age:
            X = X.drop(columns=['vehicle_age'], errors='ignore')
            
        # Drop raw columns not needed further.
        cols_to_drop = ['standard_make', 'standard_model', 'year_listed', 'month_listed', 'day_listed']
        X = X.drop(columns=cols_to_drop, errors='ignore')
        
        return X

# --- Simple Target Encoder for High-Cardinality Features
class SimpleTargetEncoder(BaseEstimator, TransformerMixin):
    """
    Target encoder for high-cardinality categorical features.
    Uses the mean target value per category with smoothing.
    """
    def __init__(self, cols=None, smoothing=10.0, min_samples_leaf=1):
        self.cols = cols if cols is not None else []
        self.smoothing = smoothing
        self.min_samples_leaf = min_samples_leaf
        self.mapping = {}
        self.global_mean = None
        
    def fit(self, X, y):
        X_temp = X.copy()
        self.global_mean = y.mean()
        for col in self.cols:
            if col not in X_temp.columns:
                continue
            stats = pd.DataFrame({
                'sum': y.groupby(X_temp[col]).sum(),
                'count': y.groupby(X_temp[col]).count()
            })
            stats['mean'] = (stats['sum'] + self.smoothing * self.global_mean) / (stats['count'] + self.smoothing)
            self.mapping[col] = stats['mean'].to_dict()
        return self
        
    def transform(self, X):
        X_temp = X.copy()
        for col in self.cols:
            if col not in X_temp.columns:
                continue
            X_temp[col] = X_temp[col].map(self.mapping.get(col, {})).fillna(self.global_mean)
        return X_temp

# --- Boolean to Int Converter
class BooleanToInt(BaseEstimator, TransformerMixin):
    """Converts boolean columns to integers (0/1)."""
    def __init__(self, cols=None):
        self.cols = cols if cols is not None else []
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        for col in self.cols:
            if col in X.columns:
                X[col] = X[col].astype(int)
        return X

# --- Log Transformer
class LogTransformer(BaseEstimator, TransformerMixin):
    """
    Applies log1p transform to specified numeric columns.
    """
    def __init__(self, cols=None):
        self.cols = cols if cols is not None else []
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        for col in self.cols:
            if col in X.columns:
                X[col] = np.log1p(X[col].clip(lower=0))
        return X

# --- Custom DataFrame One-Hot Encoder
class DataFrameOneHotEncoder(BaseEstimator, TransformerMixin):
    """
    Wraps OneHotEncoder and returns a DataFrame with appropriate column names.
    Only transforms specified columns and concatenates with the remaining columns.
    """
    def __init__(self, ohe_columns, drop='first'):
        self.ohe_columns = ohe_columns
        self.drop = drop
        self.ohe_ = OneHotEncoder(drop=self.drop, sparse_output=False, handle_unknown='ignore')
        self.feature_names_ = None
    
    def fit(self, X, y=None):
        # Fit OneHotEncoder on the specified columns.
        self.ohe_.fit(X[self.ohe_columns])
        # Get new feature names.
        self.feature_names_ = self.ohe_.get_feature_names_out(self.ohe_columns)
        return self
    
    def transform(self, X):
        X = X.copy()
        # Transform the specified columns using OneHotEncoder.
        ohe_array = self.ohe_.transform(X[self.ohe_columns])
        df_ohe = pd.DataFrame(ohe_array, columns=self.feature_names_, index=X.index)
        # Drop the original ohe_columns from X.
        X = X.drop(columns=self.ohe_columns, errors='ignore')
        # Concatenate one-hot encoded columns with the remaining columns.
        return pd.concat([df_ohe, X], axis=1)

# --- Custom Scaler that Preserves Column Names
class ScalerWithNames(StandardScaler):
    def fit(self, X, y=None):
        # Store column names.
        self.feature_names_in_ = X.columns.tolist()
        return super().fit(X, y)
    
    def transform(self, X, y=None):
        X_scaled = super().transform(X, y)
        return pd.DataFrame(X_scaled, columns=self.feature_names_in_, index=X.index)

# --- Advanced Pipeline Builder (Revised Order with Name Preservation)
def create_advanced_pipeline(
    ohe_cols=None,
    log_cols=None,
    target_encode_cols=None,
    bool_cols=None,
    luxury_brands=None,
    do_scaling=False
):
    """
    Creates an advanced pipeline that returns a DataFrame with column names.
    
    Steps:
      1) Feature engineering.
      2) Boolean-to-integer conversion.
      3) Target encoding for high-cardinality features.
      4) Label encoding for 'vehicle_condition'.
      5) Log transformation for specified numeric columns.
      6) One-hot encoding for selected low-card categorical columns (DataFrame output).
      7) (Optional) Standard scaling (preserving names).
    """
    # Set defaults.
    if ohe_cols is None:
        ohe_cols = ["fuel_type", "body_type", "standard_colour"]
    if log_cols is None:
        log_cols = ["mileage", "mileage_age_interaction", "mileage_per_year"]
    if target_encode_cols is None:
        target_encode_cols = ["standard_make_model"]
    if bool_cols is None:
        bool_cols = ["crossover_car_and_van"]
    
    # 1) Feature engineering.
    feature_step = ("feature_engineer", FeatureEngineer(
        luxury_brands=luxury_brands,
        drop_vehicle_age=False
    ))
    
    # 2) Boolean-to-int conversion.
    bool_step = ("bool_to_int", BooleanToInt(cols=bool_cols))
    
    # 3) Target encoding for high-cardinality columns.
    target_encoder_step = ("target_encoder", SimpleTargetEncoder(
        cols=target_encode_cols,
        smoothing=10.0
    ))
    
    # 4) Label encoding for 'vehicle_condition'.
    label_encoder_step = ("vehicle_condition_le", VehicleConditionLabelEncoder())
    
    # 5) Log transformation.
    log_step = ("log_transform", LogTransformer(cols=log_cols))
    
    # 6) One-hot encoding using custom DataFrameOneHotEncoder.
    one_hot_step = ("one_hot_encoder", DataFrameOneHotEncoder(ohe_columns=ohe_cols, drop='first'))
    
    # Assemble pipeline steps.
    steps = [
        feature_step,
        bool_step,
        target_encoder_step,
        label_encoder_step,
        log_step,
        one_hot_step
    ]
    
    # 7) Optional scaling with column names.
    if do_scaling:
        steps.append(("scaler", ScalerWithNames()))
    
    pipeline = Pipeline(steps)
    return pipeline

# --- Data Split Function
def prepare_data_splits(df, target_col='price', test_size=0.2, val_size=0.25, random_state=42):
    """
    Splits the data into training, validation, and test sets.
    """
    y = df[target_col]
    X = df.drop(columns=[target_col])
    X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=val_size, random_state=random_state)

    y_train_log = np.log1p(y_train)  # log1p = log(1+x) avoids issues with zeros
    y_val_log = np.log1p(y_val)
    y_test_log = np.log1p(y_test)

    print(f"Training set: {X_train.shape[0]} samples")
    print(f"Validation set: {X_val.shape[0]} samples")
    print(f"Test set: {X_test.shape[0]} samples")

    return X_train, X_val, X_test, y_train_log, y_val_log, y_test_log, y_train, y_val, y_test

# %%
if __name__ == "__main__":
    # Assume 'car_auto_cl' is your pre-cleaned DataFrame with target 'price'.
    car_auto_fin = car_auto_cl.copy()
    
    # Define parameters.
    ohe_cols = ["fuel_type", "body_type", "standard_colour"]
    log_cols = ["mileage", "mileage_age_interaction", "mileage_per_year"]
    target_encode_cols = ["standard_make_model"]
    bool_cols = ["crossover_car_and_van"]
    luxury_brands = [
        'mercedes-benz', 'bmw', 'audi', 'lexus', 'porsche', 
        'jaguar', 'land rover', 'bentley', 'maserati', 'ferrari', 'lamborghini'
    ]
    
    # Create train/validation/test splits.
    X_train, X_val, X_test, y_train_log, y_val_log, y_test_log, y_train, y_val, y_test = prepare_data_splits(car_auto_fin, target_col='price')
    
    # Build pipeline. Set do_scaling=True for linear/polynomial models, False for tree-based.
    advanced_pipeline = create_advanced_pipeline(
        ohe_cols=ohe_cols,
        log_cols=log_cols,
        target_encode_cols=target_encode_cols,
        bool_cols=bool_cols,
        luxury_brands=luxury_brands,
        do_scaling=False  # change to True if needed
    )
    
    # Fit the pipeline on training data (y_train is used for target encoding).
    advanced_pipeline.fit(X_train, y_train_log)
    
    # Transform train, validation, and test sets.
    X_train_final = advanced_pipeline.transform(X_train)
    X_val_final = advanced_pipeline.transform(X_val)
    X_test_final = advanced_pipeline.transform(X_test)
    
    print("Training final shape:", X_train_final.shape)
    print("Validation final shape:", X_val_final.shape)
    print("Test final shape:", X_test_final.shape)
# Out:
# Training set: 241203 samples
# Validation set: 80401 samples
# Test set: 80401 samples
# Training final shape: (241203, 35)
# Validation final shape: (80401, 35)
# Test final shape: (80401, 35)

# %%
create_advanced_pipeline()
# Out:
# Pipeline(steps=[('feature_engineer',
#                  FeatureEngineer(luxury_brands=['mercedes-benz', 'bmw', 'audi',
#                                                 'lexus', 'porsche', 'jaguar',
#                                                 'land rover', 'bentley',
#                                                 'maserati', 'ferrari',
#                                                 'lamborghini'])),
#                 ('bool_to_int', BooleanToInt(cols=['crossover_car_and_van'])),
#                 ('target_encoder',
#                  SimpleTargetEncoder(cols=['standard_make_model'])),
#                 ('vehicle_condition_le', VehicleConditionLabelEncoder()),
#                 ('log_transform',
#                  LogTransformer(cols=['mileage', 'mileage_age_interaction',
#                                       'mileage_per_year'])),
#                 ('one_hot_encoder',
#                  DataFrameOneHotEncoder(ohe_columns=['fuel_type', 'body_type',
# ...

# %%
X_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241203 entries, 284701 to 157493
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   fuel_type_Diesel                     241203 non-null  float64
#  1   fuel_type_Electric                   241203 non-null  float64
#  2   fuel_type_Hybrid                     241203 non-null  float64
#  3   fuel_type_Petrol                     241203 non-null  float64
#  4   body_type_Coupe                      241203 non-null  float64
#  5   body_type_Estate                     241203 non-null  float64
#  6   body_type_Hatchback                  241203 non-null  float64
#  7   body_type_Luxury/Passenger Vehicles  241203 non-null  float64
#  8   body_type_MPV                        241203 non-null  float64
#  9   body_type_SUV                        241203 non-null  float64
# ...

# %%
enc = advanced_pipeline.named_steps["target_encoder"]
mapping = enc.mapping["standard_make_model"]
# turn into DataFrame
mp = pd.DataFrame.from_dict(mapping, orient="index", columns=["te_mean"])
mp = mp.sort_values("te_mean", ascending=False).head(20)
mp.plot.barh(figsize=(6,4))
plt.title("Top 20 standard_make_model by target-encoded mean price")
plt.xlabel("Encoded mean(log price)")
plt.show()

# %% [markdown]
# “Figure X: Target-encoding map for standard_make_model. The 20 highest-valued categories are all luxury/exotic vehicles, indicating the encoder has learned a realistic prior for price and confirming the effectiveness of our smoothing parameter (λ = 10).”

# %%
# ── % missing in raw data  ───────────────────────────────────────────
before = car_auto.isna().mean().mul(100).round(2)

# % missing after the pipeline (train fold)
after = pd.DataFrame(X_train_final).isna().mean().mul(100).round(2)
after.index = X_train_final.columns          # current feature names

# --- ALIGN INDICES ---------------------------------------------------
# bring `after` onto the *raw* column index; cols that were dropped/created
# get NaN (fill with 0 for plotting clarity)
after_reindexed = after.reindex(before.index).fillna(0)

# ---------------------------------------------------------------------
na_df = (pd.concat({"Before": before, "After": after_reindexed}, axis=1)
           .loc[before.gt(0)]                    # only columns that had NAs
           .sort_values("Before", ascending=False))

# ── Plot ─────────────────────────────────────────────────────────────
sns.set_style("whitegrid")
ax = na_df.plot(kind="barh", figsize=(6, 4), width=0.85,
                color=["firebrick", "steelblue"])

ax.set_xlabel("% of missing values")
ax.set_title("Missing values: raw vs after-pipeline (train set)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 2. Automated Feature Selection

# %% [markdown]
# 1. RFE vs. From-Model vs. SFS:
#
# RFE:
#
# Pros: Relatively easy to set up, uses the model’s estimates to recursively reduce features.
#
# Cons: Can be computationally expensive if you remove one feature at a time; may be unstable if the model is sensitive to data splits.
#
# From-Model Feature Importance:
#
# Pros: Requires training just one model (or a few) and is very fast.
#
# Cons: Importance is model-specific; results may differ significantly depending on the estimator chosen.
#
# Sequential Feature Selection (SFS):
#
# Pros: Provides a systematic search (either forward or backward), can be tuned with cross-validation.
#
# Cons: Computationally expensive and may get stuck in local minima, since it’s a greedy algorithm.

# %% [markdown]
# ### RFE (RECURSIVE FEATURE ELIMINATION)

# %% [markdown]
# RFE so far is computationally slow

# %%
def run_rfe_optimized(X, y, n_features_to_select=10, estimator=None):
    """
    Optimized RFE implementation with:
    - Larger step size
    - Lighter default estimator
    - Optional parallel processing
    """
    if estimator is None:
        # Use a simpler estimator for initial selection
        estimator = RandomForestRegressor(
            n_estimators=100, 
            max_depth=10,      # Limit tree depth
            n_jobs=-1,        # Use all CPU cores
            random_state=42
        )
    
    # Increase step size based on feature count
    step_size = max(2, (X.shape[1] - n_features_to_select) // 10)
    
    # Create RFE selector
    rfe_selector = RFE(
        estimator=estimator,
        n_features_to_select=n_features_to_select,
        step=step_size,
        verbose=1  # Add progress reporting
    )
    
    print(f"Starting RFE with {X.shape[1]} features...")
    print(f"Step size: {step_size}")
    
    # Fit RFE
    rfe_selector.fit(X, y)
    
    # Get selected features
    selected_features = X.columns[rfe_selector.support_]
    
    # Quick cross-validation on final feature set
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(
        estimator, 
        X[selected_features], 
        y,
        scoring='neg_mean_squared_error',
        cv=cv,
        n_jobs=-1  # Parallel CV
    )
    rmse_scores = np.sqrt(-scores)
    
    print("\nRFE selected features:")
    print(selected_features.tolist())
    print(f"RFE CV RMSE: Mean = {rmse_scores.mean():.2f}, Std = {rmse_scores.std():.2f}")
    
    return selected_features, rfe_selector, rmse_scores

# Usage with progress monitoring
start_time = time()
rfe_features, rfe_selector, rfe_scores = run_rfe_optimized(X_train_final, y_train_log, n_features_to_select=15)
print(f"\nTotal time: {time() - start_time:.2f} seconds")
# Out:
# Starting RFE with 35 features...
# Step size: 2
# Fitting estimator with 35 features.
# Fitting estimator with 33 features.
# Fitting estimator with 31 features.
# Fitting estimator with 29 features.
# Fitting estimator with 27 features.
# Fitting estimator with 25 features.
# Fitting estimator with 23 features.
# Fitting estimator with 21 features.
# Fitting estimator with 19 features.
# Fitting estimator with 17 features.
#
# RFE selected features:
# ['fuel_type_Hybrid', 'fuel_type_Petrol', 'body_type_Coupe', 'body_type_Hatchback', 'body_type_MPV', 'body_type_SUV', 'body_type_Saloon', 'mileage', 'year_of_registration', 'vehicle_age', 'mileage_per_year', 'mileage_age_interaction', 'listing_month_day', 'standard_make_model', 'is_luxury_brand']
# RFE CV RMSE: Mean = 0.25, Std = 0.00
#
# Total time: 428.89 seconds

# %% [markdown]
# Starting RFE with 35 features...
# Step size: 2
# Fitting estimator with 35 features.
# Fitting estimator with 33 features.
# Fitting estimator with 31 features.
# Fitting estimator with 29 features.
# Fitting estimator with 27 features.
# Fitting estimator with 25 features.
# Fitting estimator with 23 features.
# Fitting estimator with 21 features.
# Fitting estimator with 19 features.
# Fitting estimator with 17 features.
#
# RFE selected features:
# ['fuel_type_Hybrid', 'fuel_type_Petrol', 'body_type_Coupe', 'body_type_Hatchback', 'body_type_MPV', 'body_type_SUV', 'body_type_Saloon', 'mileage', 'year_of_registration', 'vehicle_age', 'mileage_per_year', 'mileage_age_interaction', 'listing_month_day', 'standard_make_model', 'is_luxury_brand']
# RFE CV RMSE: Mean = 0.25, Std = 0.00
#
# Total time: 163.65 seconds

# %% [markdown]
# ### SELECT KBEST

# %% [markdown]
# SelectKBest uses a univariate statistical test (here, F‑regression for regression tasks) to rank features individually by their correlation with the target. It then selects the top k features. This method is fast and can serve as a baseline.

# %%
def run_select_kbest(X, y, k=10):
    """
    Runs SelectKBest with F-regression test and time tracking.
    
    Parameters:
      X (DataFrame): Training features.
      y (Series): Target variable.
      k (int): Number of top features to select.
      
    Returns:
      selected_features: List of selected feature names.
      selector: The fitted SelectKBest object.
      cv_scores: Cross-validation scores using a simple estimator on the selected features.
    """
    start_time = time()
    
    print(f"Starting SelectKBest with {X.shape[1]} features...")
    print(f"Target features: {k}")
    
    selector = SelectKBest(score_func=f_regression, k=k)
    X_new = selector.fit_transform(X, y)
    
    # Get the indices of selected features and convert to column names
    mask = selector.get_support()
    selected_features = X.columns[mask]
    
    print("\nSelectKBest selected features:")
    print(selected_features.tolist())
    
    # Evaluate via cross-validation
    estimator = LinearRegression()
    cv = KFold(n_splits=5, shuffle=True, random_state=random_state)
    scores = cross_val_score(
        estimator, 
        X[selected_features], 
        y, 
        scoring='neg_mean_squared_error',
        cv=cv,
        n_jobs=-1  # Parallel processing
    )
    rmse_scores = np.sqrt(-scores)
    print(f"SelectKBest CV RMSE: Mean = {rmse_scores.mean():.2f}, Std = {rmse_scores.std():.2f}")
    print(f"\nTotal time: {time() - start_time:.2f} seconds")
    
    return selected_features, selector, rmse_scores

print("Running SelectKBest...")
kbest_features, kbest_selector, kbest_scores = run_select_kbest(X_train_final, y_train_log, k=15)
# Out:
# Running SelectKBest...
# Starting SelectKBest with 35 features...
# Target features: 15
#
# SelectKBest selected features:
# ['fuel_type_Electric', 'fuel_type_Hybrid', 'fuel_type_Petrol', 'body_type_Coupe', 'body_type_Hatchback', 'body_type_SUV', 'standard_colour_Silver', 'mileage', 'vehicle_condition', 'year_of_registration', 'vehicle_age', 'mileage_age_interaction', 'listing_month_day', 'standard_make_model', 'is_luxury_brand']
# SelectKBest CV RMSE: Mean = 0.38, Std = 0.00
#
# Total time: 1.56 seconds

# %% [markdown]
# Running SelectKBest...
# Starting SelectKBest with 35 features...
# Target features: 15
#
# SelectKBest selected features:
# ['fuel_type_Electric', 'fuel_type_Hybrid', 'fuel_type_Petrol', 'body_type_Coupe', 'body_type_Hatchback', 'body_type_SUV', 'standard_colour_Silver', 'mileage', 'vehicle_condition', 'year_of_registration', 'vehicle_age', 'mileage_age_interaction', 'listing_month_day', 'standard_make_model', 'is_luxury_brand']
# SelectKBest CV RMSE: Mean = 0.38, Std = 0.00
#
# Total time: 1.69 seconds

# %% [markdown]
# ### SEQUENTIAL FEATURE SELECTION

# %% [markdown]
# Sequential Feature Selector (SFS) can either add (forward selection) or remove (backward selection) features one by one based on how much the inclusion or exclusion improves model performance (measured via cross‑validation). Here we use a forward selection process with a RandomForestRegressor.

# %%
def run_simple_sfs(X, y, n_features_to_select=10, direction='forward'):
    """
    Simple Sequential Feature Selection implementation.
    
    Parameters:
        X: Feature DataFrame
        y: Target variable
        n_features_to_select: Number of features to select
        direction: 'forward' or 'backward' selection
    """
    start_time = time()
    
    # Simple RandomForestRegressor as estimator
    estimator = RandomForestRegressor(
        n_estimators= 10,  # Reduced number of trees
        max_depth= 4,      # Limited depth
        min_samples_leaf=5,
        random_state=random_state,
        n_jobs=-1  # Use all CPU cores
    )
    
    print(f"Starting SFS ({direction}) with {X.shape[1]} features...")
    print(f"Target features: {n_features_to_select}")
    
    # Create SFS with simple parameters
    sfs = SequentialFeatureSelector(
        estimator,
        n_features_to_select=n_features_to_select,
        direction=direction,
        cv=3,  # Reduced CV folds
        n_jobs=-1,
        scoring='neg_mean_squared_error'
    )
    
    # Fit SFS
    sfs.fit(X, y)
    
    # Get selected features
    selected_features = X.columns[sfs.get_support()]
    
    print(f"\nSFS selected features ({direction}):")
    print(selected_features.tolist())
    
    # Quick evaluation
    cv = KFold(n_splits=3, shuffle=True, random_state=random_state)
    scores = cross_val_score(
        estimator,
        X[selected_features],
        y,
        scoring='neg_mean_squared_error',
        cv=cv,
        n_jobs=-1
    )
    
    rmse_scores = np.sqrt(-scores)
    print(f"SFS CV RMSE: Mean = {rmse_scores.mean():.2f}, Std = {rmse_scores.std():.2f}")
    print(f"\nTotal time: {time() - start_time:.2f} seconds")
    
    return selected_features, sfs, rmse_scores

# Usage
print("Running Simple Sequential Feature Selection...")
sfs_features, sfs_selector, sfs_scores = run_simple_sfs(
    X_train_final, 
    y_train_log,
    n_features_to_select=15,
    direction='forward'
)
# Out:
# Running Simple Sequential Feature Selection...
# Starting SFS (forward) with 35 features...
# Target features: 15
#
# SFS selected features (forward):
# ['fuel_type_Diesel', 'fuel_type_Petrol', 'body_type_Estate', 'body_type_Hatchback', 'body_type_Luxury/Passenger Vehicles', 'body_type_MPV', 'body_type_SUV', 'standard_colour_Blue', 'standard_colour_Silver', 'standard_colour_Unknown', 'standard_colour_White', 'standard_colour_Yellow', 'mileage', 'mileage_age_interaction', 'standard_make_model']
# SFS CV RMSE: Mean = 0.37, Std = 0.00
#
# Total time: 469.88 seconds

# %% [markdown]
# Running Simple Sequential Feature Selection...
# Starting SFS (forward) with 35 features...
# Target features: 15
#
# SFS selected features (forward):
# ['fuel_type_Diesel', 'fuel_type_Hybrid', 'fuel_type_Petrol', 'body_type_Coupe', 'body_type_Estate', 'body_type_Hatchback', 'body_type_MPV', 'body_type_SUV', 'mileage', 'year_of_registration', 'mileage_per_year', 'mileage_age_interaction', 'listing_month_day', 'standard_make_model', 'is_luxury_brand']
# SFS CV RMSE: Mean = 0.27, Std = 0.00
#
# Total time: 1950.05 seconds

# %% [markdown]
#  RFE for automated feature selection in your tree ensemble project.
#
# Justification:
#
# Lower CV RMSE: 0.25 compared to 0.27 (SFS) and 0.38 (SelectKBest) indicates better predictive performance.
#
# Reasonable Runtime: About 2–3 minutes is acceptable for a dataset with 35 features, whereas SFS took considerably longer.
#
# Multivariate Consideration: RFE accounts for interactions among features, leading to a robust subset that aligns with your domain knowledge and model needs.

# %%
# -----------------------------------------
#  put this in a cell AFTER you have run
#  the three selector functions
# -----------------------------------------
#  store the lists of features
selected_dict = {
    "RFE"   : rfe_features.tolist(),
    "SFS"   : sfs_features.tolist(),
    "KBest" : kbest_features.tolist()
}

# store the performance (mean CV-RMSE you printed)
cv_rmse  = {
    "RFE"   : rfe_scores.mean(),
    "SFS"   : sfs_scores.mean(),
    "KBest" : kbest_scores.mean()
}

#   create a tidy boolean matrix (feature × method)
all_feats = sorted(set(sum(selected_dict.values(), [])))
heat_df   = pd.DataFrame({m : [f in lst for f in all_feats]
                          for m,lst in selected_dict.items()},
                         index = all_feats)

palette   = sns.color_palette("Set2", 3)     # shared palette

# %%
plt.figure(figsize=(6, 0.25*len(all_feats)+1))
sns.heatmap(heat_df,
            cmap=sns.light_palette("steelblue", as_cmap=True),
            cbar=False, linewidths=.5, linecolor='lightgrey')
plt.title("Feature inclusion across selectors")
plt.xlabel("Selector");  plt.ylabel("Feature name")
plt.show()

# %%
pd.Series(cv_rmse).sort_values().plot.bar(color=palette, rot=0)
plt.ylabel("Mean CV RMSE (log-scale)")
plt.title("Selector performance (↓ better)")
for i,v in enumerate(pd.Series(cv_rmse).sort_values()):
    plt.text(i, v+0.005, f"{v:.3f}", ha='center')
plt.show()

# %%
rank_df = (
    pd.concat([
        pd.DataFrame({"feature": rfe_features,
                      "rank":   range(1, len(rfe_features)+1),
                      "method": "RFE"}),
        pd.DataFrame({"feature": sfs_features,
                      "rank":   range(1, len(sfs_features)+1),
                      "method": "SFS"})
    ])
)

plt.figure(figsize=(7,4))
sns.stripplot(data=rank_df, x="rank", y="feature",
              hue="method", palette=palette, size=7)
plt.xlim(0.5, 15.5); plt.gca().invert_xaxis()
plt.title("Order in which features were selected")
plt.legend(bbox_to_anchor=(1.02,1)); plt.tight_layout(); plt.show()

# %%
selector_df = pd.DataFrame({
    "Selector": ["RFE", "SFS", "SelectKBest"],
    "CV_RMSE":  [rfe_scores.mean(), sfs_scores.mean(), kbest_scores.mean()]
}).sort_values("CV_RMSE")

selector_df.plot(kind="barh", x="Selector", y="CV_RMSE",
                 legend=False, color="darkcyan", figsize=(5, 3))
plt.xlabel("CV-RMSE (log £)  ↓ better")
plt.title("Automated feature-selection comparison")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. Tree Ensembles

# %%
# Subset the transformed datasets to include only the selected features.
X_train_sel = X_train_final[rfe_features]
X_val_sel   = X_val_final[rfe_features]
X_test_sel  = X_test_final[rfe_features]

# %% [markdown]
# ### Random Forest Regressor

# %%
# --- Optimized RandomForestRegressor ---
rf_model = RandomForestRegressor(
    n_estimators= 300,          # More trees for better stability
    max_depth=17,             # Limit depth to prevent overfitting
    min_samples_split= 5,     # Require more samples to split
    min_samples_leaf= 1,       # Require more samples in leaves
    max_features='sqrt',      # Standard RF feature sampling
    n_jobs=-1,               # Use all CPU cores
    random_state=42
)

# Fit the model
rf_model.fit(X_train_sel, y_train_log)

# Make predictions on all sets
y_train_pred_rf = rf_model.predict(X_train_sel)
y_val_pred_rf = rf_model.predict(X_val_sel)
y_test_pred_rf = rf_model.predict(X_test_sel)

# Calculate RMSE for all sets
rf_rmse_train = np.sqrt(mean_squared_error(y_train_log, y_train_pred_rf))
rf_rmse_val = np.sqrt(mean_squared_error(y_val_log, y_val_pred_rf))
rf_rmse_test = np.sqrt(mean_squared_error(y_test_log, y_test_pred_rf))

# Calculate R² scores
r2_train = r2_score(y_train_log, y_train_pred_rf)
r2_val = r2_score(y_val_log, y_val_pred_rf)
r2_test = r2_score(y_test_log, y_test_pred_rf)

# Print results
print("Random Forest Performance Metrics (log-scale):")
print(f"Training RMSE: {rf_rmse_train:.3f}")
print(f"Validation RMSE: {rf_rmse_val:.3f}")
print(f"Test RMSE: {rf_rmse_test:.3f}")
print("\nR² Scores:")
print(f"Training R²: {r2_train:.3f}")
print(f"Validation R²: {r2_val:.3f}")
print(f"Test R²: {r2_test:.3f}")

# Optional: Convert predictions back to original scale and calculate error metrics
y_train_pred_orig = np.expm1(y_train_pred_rf)
y_val_pred_orig = np.expm1(y_val_pred_rf)
y_test_pred_orig = np.expm1(y_test_pred_rf)

mae_train = mean_absolute_error(y_train, y_train_pred_orig)
mae_val = mean_absolute_error(y_val, y_val_pred_orig)
mae_test = mean_absolute_error(y_test, y_test_pred_orig)

print("\nMean Absolute Error (original scale):")
print(f"Training MAE: £{mae_train:,.0f}")
print(f"Validation MAE: £{mae_val:,.0f}")
print(f"Test MAE: £{mae_test:,.0f}")
# Out:
# Random Forest Performance Metrics (log-scale):
# Training RMSE: 0.181
# Validation RMSE: 0.229
# Test RMSE: 0.226
#
# R² Scores:
# Training R²: 0.956
# Validation R²: 0.928
# Test R²: 0.929
#
# Mean Absolute Error (original scale):
# Training MAE: £2,484
# Validation MAE: £2,755
# Test MAE: £2,844

# %% [markdown]
# Random Forest Performance Metrics (log-scale):
# Training RMSE: 0.181
# Validation RMSE: 0.229
# Test RMSE: 0.226
#
# R² Scores:
# Training R²: 0.956
# Validation R²: 0.928
# Test R²: 0.929
#
# Mean Absolute Error (original scale):
# Training MAE: £2,484
# Validation MAE: £2,755
# Test MAE: £2,844

# %% [markdown]
# High R² (around 0.92–0.93) indicates that your model captures the majority of the variance.
#
# Consistent RMSE values across training, validation, and test sets indicate low overfitting.
#
# MAE around £3,000 on the original scale suggests that, on average, predictions are reasonably close to actual prices relative to the typical price range.
#
# Overall, these results look good for a Random Forest model in a car price prediction task, assuming that an average error of £3,000 is within acceptable bounds in your domain.

# %% [markdown]
# ### XGBoost

# %%
# --- XGBoost Implementation ---
print("Training XGBoost model...")
xgb_model = xgb.XGBRegressor(
    n_estimators= 464,
    learning_rate=0.1,
    max_depth = 10,
    min_child_weight=3,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0,
    reg_alpha=0.1,
    reg_lambda=1,
    random_state=42,
    n_jobs=-1
)

# Train XGBoost
xgb_model.fit(X_train_sel, y_train_log)

# Predictions
xgb_train_pred = xgb_model.predict(X_train_sel)
xgb_val_pred = xgb_model.predict(X_val_sel)
xgb_test_pred = xgb_model.predict(X_test_sel)

# Convert back to original scale
xgb_train_pred_orig = np.expm1(xgb_train_pred)
xgb_val_pred_orig = np.expm1(xgb_val_pred)
xgb_test_pred_orig = np.expm1(xgb_test_pred)

# Calculate metrics (Log scale)
print("\nXGBoost Performance Metrics:")
print("Log-scale metrics:")
print("-" * 50)
print("MSE:")
print(f"Training MSE: {mean_squared_error(y_train_log, xgb_train_pred):.3f}")
print(f"Validation MSE: {mean_squared_error(y_val_log, xgb_val_pred):.3f}")
print(f"Test MSE: {mean_squared_error(y_test_log, xgb_test_pred):.3f}")

print("\nRMSE:")
print(f"Training RMSE: {np.sqrt(mean_squared_error(y_train_log, xgb_train_pred)):.3f}")
print(f"Validation RMSE: {np.sqrt(mean_squared_error(y_val_log, xgb_val_pred)):.3f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test_log, xgb_test_pred)):.3f}")

print("\nMAE:")
print(f"Training MAE: {mean_absolute_error(y_train_log, xgb_train_pred):.3f}")
print(f"Validation MAE: {mean_absolute_error(y_val_log, xgb_val_pred):.3f}")
print(f"Test MAE: {mean_absolute_error(y_test_log, xgb_test_pred):.3f}")

print("\nR² Score:")
print(f"Training R²: {r2_score(y_train_log, xgb_train_pred):.3f}")
print(f"Validation R²: {r2_score(y_val_log, xgb_val_pred):.3f}")
print(f"Test R²: {r2_score(y_test_log, xgb_test_pred):.3f}")
# Out:
# Training XGBoost model...
#
# XGBoost Performance Metrics:
# Log-scale metrics:
# --------------------------------------------------
# MSE:
# Training MSE: 0.018
# Validation MSE: 0.040
# Test MSE: 0.040
#
# RMSE:
# Training RMSE: 0.133
# Validation RMSE: 0.201
# Test RMSE: 0.199
#
# MAE:
# Training MAE: 0.097
# Validation MAE: 0.131
# Test MAE: 0.129
#
# R² Score:
# Training R²: 0.976
# Validation R²: 0.945
# Test R²: 0.945

# %% [markdown]
# Training XGBoost model...
#
# XGBoost Performance Metrics:
# Log-scale metrics:
# MSE:
# Training MSE: 0.038
# Validation MSE: 0.045
# Test MSE: 0.044
#
# RMSE:
# Training RMSE: 0.195
# Validation RMSE: 0.211
# Test RMSE: 0.209
#
# MAE:
# Training MAE: 0.137
# Validation MAE: 0.142
# Test MAE: 0.142
#
# R² Score:
# Training R²: 0.948
# Validation R²: 0.939
# Test R²: 0.940

# %% [markdown]
# ### LightGBM

# %%
# --- LightGBM Implementation ---
print("\nTraining LightGBM model...")
lgb_model = lgb.LGBMRegressor(
    n_estimators= 300,
    learning_rate=0.1,
    max_depth=7,
    num_leaves=31,
    min_child_samples=20,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1,
    random_state=42,
    n_jobs=-1
)

# Train LightGBM
lgb_model.fit(X_train_sel, y_train_log)

# Predictions
lgb_train_pred = lgb_model.predict(X_train_sel)
lgb_val_pred = lgb_model.predict(X_val_sel)
lgb_test_pred = lgb_model.predict(X_test_sel)

# Convert back to original scale
lgb_train_pred_orig = np.expm1(lgb_train_pred)
lgb_val_pred_orig = np.expm1(lgb_val_pred)
lgb_test_pred_orig = np.expm1(lgb_test_pred)

# Calculate metrics
print("\nLightGBM Performance Metrics:")
print("Log-scale metrics:")
print("-" * 50)
print("MSE:")
print(f"Training MSE: {mean_squared_error(y_train_log, lgb_train_pred):.3f}")
print(f"Validation MSE: {mean_squared_error(y_val_log, lgb_val_pred):.3f}")
print(f"Test MSE: {mean_squared_error(y_test_log, lgb_test_pred):.3f}")

print("\nRMSE:")
print(f"Training RMSE: {np.sqrt(mean_squared_error(y_train_log, lgb_train_pred)):.3f}")
print(f"Validation RMSE: {np.sqrt(mean_squared_error(y_val_log, lgb_val_pred)):.3f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test_log, lgb_test_pred)):.3f}")

print("\nMAE (Log-scale):")
print(f"Training MAE: {mean_absolute_error(y_train_log, lgb_train_pred):.3f}")
print(f"Validation MAE: {mean_absolute_error(y_val_log, lgb_val_pred):.3f}")
print(f"Test MAE: {mean_absolute_error(y_test_log, lgb_test_pred):.3f}")

print("\nR² Score (Log-scale):")
print(f"Training R²: {r2_score(y_train_log, lgb_train_pred):.3f}")
print(f"Validation R²: {r2_score(y_val_log, lgb_val_pred):.3f}")
print(f"Test R²: {r2_score(y_test_log, lgb_test_pred):.3f}")
# Out:
# Training LightGBM model...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003181 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1392
# [LightGBM] [Info] Number of data points in the train set: 241203, number of used features: 15
# [LightGBM] [Info] Start training from score 9.389070
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# LightGBM Performance Metrics:
# Log-scale metrics:
# --------------------------------------------------
# MSE:
# Training MSE: 0.040
# Validation MSE: 0.044
# Test MSE: 0.043
#
# RMSE:
# Training RMSE: 0.200
# Validation RMSE: 0.210
# Test RMSE: 0.207
#
# MAE (Log-scale):
# Training MAE: 0.138
# Validation MAE: 0.142
# Test MAE: 0.141
#
# R² Score (Log-scale):
# Training R²: 0.946
# Validation R²: 0.940
# Test R²: 0.941

# %%
## Evalation of models
def rmse(y_true, y_pred):                 # tiny helper
    return np.sqrt(mean_squared_error(y_true, y_pred))

results = {
    "Random Forest": {
        "Val_RMSE":  rmse(y_val_log,  y_val_pred_rf),
        "Test_RMSE": rmse(y_test_log, y_test_pred_rf),
        "params":    f"trees={rf_model.n_estimators}, depth={rf_model.max_depth}"
    },
    "XGBoost": {
        "Val_RMSE":  rmse(y_val_log,  xgb_val_pred),
        "Test_RMSE": rmse(y_test_log, xgb_test_pred),
        "params":    f"trees={xgb_model.n_estimators}, lr={xgb_model.learning_rate}"
    },
    "LightGBM": {
        "Val_RMSE":  rmse(y_val_log,  lgb_val_pred),
        "Test_RMSE": rmse(y_test_log, lgb_test_pred),
        "params":    f"trees={lgb_model.n_estimators}, lr={lgb_model.learning_rate}"
    }
}

leader = (
    pd.DataFrame(results)
      .T
      .rename(columns={"Val_RMSE":"Val RMSE (log £)",
                       "Test_RMSE":"Test RMSE (log £)",
                       "params":"Key params"})
      .round(3)
)

display(leader)              # nice HTML table in a notebook
print(leader.to_markdown())   # or Markdown for your PDF
# Out:
#               Val RMSE (log £) Test RMSE (log £)           Key params
# Random Forest         0.229359           0.22637  trees=300, depth=17
# XGBoost               0.201189          0.198809    trees=464, lr=0.1
# LightGBM              0.210255          0.207369    trees=300, lr=0.1
# |               |   Val RMSE (log £) |   Test RMSE (log £) | Key params          |
# |:--------------|-------------------:|--------------------:|:--------------------|
# | Random Forest |           0.229359 |            0.22637  | trees=300, depth=17 |
# | XGBoost       |           0.201189 |            0.198809 | trees=464, lr=0.1   |
# | LightGBM      |           0.210255 |            0.207369 | trees=300, lr=0.1   |

# %%
sns.set_palette("Set2")
leader[["Val RMSE (log £)", "Test RMSE (log £)"]].plot.bar(rot=0, figsize=(6,4))
plt.ylabel("RMSE (log £)")
plt.title("Model leaderboard")
plt.tight_layout(); plt.show()

# %% [markdown]
# XGBoost has the smallest RMSE on both validation (≈ 0.200) and test (≈ 0.198).
# That means, among the three, it delivers the most accurate price predictions and generalises best.
#
# LightGBM comes second, a hair above 0.21 log £.
#
# Random Forest trails the others by ~0.02 log £ – roughly 2 % higher error – on both splits.

# %%
importances = pd.DataFrame({
    "Feature"    : X_train_sel.columns,
    "RF"         : rf_model.feature_importances_,
    "XGB"        : xgb_model.feature_importances_,
    "LightGBM"   : lgb_model.feature_importances_
}).set_index("Feature")

top = (importances
       .apply(lambda s: 100*s/s.sum())     # convert to %
       .sort_values("XGB", ascending=False)
       .head(15))

top.plot.barh(figsize=(6,5))
plt.title("Top 15 split-based importances (share %)"); 
plt.xlabel("Importance % of total splits"); plt.gca().invert_yaxis()
plt.tight_layout(); plt.show()

# %%
# Compare feature importances
def plot_feature_importance(model, model_name):
    importances = pd.DataFrame({
        'feature': X_train_sel.columns,
        'importance': model.feature_importances_
    })
    importances = importances.sort_values('importance', ascending=False)
    
    plt.figure(figsize=(10, 6))
    sns.barplot(data=importances.head(15), x='importance', y='feature')
    plt.title(f'{model_name} Feature Importance')
    plt.tight_layout()
    plt.show()

# Plot feature importance for all three models
plot_feature_importance(rf_model, 'Random Forest')
plot_feature_importance(xgb_model, 'XGBoost')
plot_feature_importance(lgb_model, 'LightGBM')

# %% [markdown]
# ### GRIDSEARCHCV

# %%
# Simple GridSearchCV
def simple_grid_search(X_train, y_train):
    param_grid = {
        'n_estimators': [100, 200],
        'max_depth': [10, 15],
        'min_samples_split': [5, 10]
    }
    
    rf = RandomForestRegressor(random_state=42)
    grid_search = GridSearchCV(
        rf, param_grid,
        cv=5,
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )
    
    grid_search.fit(X_train, y_train)
    print("Best parameters:", grid_search.best_params_)
    print("Best RMSE:", np.sqrt(-grid_search.best_score_))
    
    return grid_search.best_estimator_

# %%
# Optimized GridSearchCV
def optimized_grid_search(X_train, y_train):
    # First rough search
    rough_param_grid = {
        'n_estimators': [100, 300],
        'max_depth': [7, 15],
        'min_samples_split': [5, 15],
        'min_samples_leaf': [2, 6]
    }
    
    rf = RandomForestRegressor(random_state=42)
    rough_search = GridSearchCV(
        rf, rough_param_grid,
        cv=3,  # Fewer CV splits for speed
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )
    
    rough_search.fit(X_train, y_train)
    best_params = rough_search.best_params_
    
    # Fine-tuned search around best parameters
    fine_param_grid = {
        'n_estimators': [best_params['n_estimators'] - 50, best_params['n_estimators'], best_params['n_estimators'] + 50],
        'max_depth': [best_params['max_depth'] - 2, best_params['max_depth'], best_params['max_depth'] + 2],
        'min_samples_split': [best_params['min_samples_split'] - 2, best_params['min_samples_split'], best_params['min_samples_split'] + 2],
        'min_samples_leaf': [best_params['min_samples_leaf'] - 1, best_params['min_samples_leaf'], best_params['min_samples_leaf'] + 1]
    }
    
    fine_search = GridSearchCV(
        rf, fine_param_grid,
        cv=5,
        scoring='neg_mean_squared_error',
        n_jobs=-1
    )
    
    fine_search.fit(X_train, y_train)
    print("Best parameters:", fine_search.best_params_)
    print("Best RMSE:", np.sqrt(-fine_search.best_score_))
    
    return fine_search.best_estimator_

# %%
# # Simple version
# best_rf_simple = simple_grid_search(X_train_sel, y_train_log)

# %% [markdown]
# Best parameters: {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 200}
# Best RMSE: 0.20660709052436885

# %%
# # # Optimized version
# best_rf_optimized = optimized_grid_search(X_train_sel, y_train_log)

# %% [markdown]
# Best parameters: {'max_depth': 17, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# Best RMSE: 0.2025151872812925

# %% [markdown]
# ### OPTUNA

# %%
import optuna
from sklearn.model_selection import cross_val_score, KFold
import xgboost as xgb
import numpy as np

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 600),
        "max_depth":    trial.suggest_int("max_depth", 4, 10),
        "learning_rate":trial.suggest_float("lr", 1e-3, 0.3, log=True),
        "subsample":    trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample", 0.5, 1.0),
        "reg_lambda":   trial.suggest_float("l2", 1e-3, 10.0, log=True),
        "random_state": 42,
        "n_jobs": -1,
        "tree_method": "hist"
    }
    model = xgb.XGBRegressor(**params)
    cv = KFold(n_splits=3, shuffle=True, random_state=42)
    rmse = -cross_val_score(model, X_train_sel, y_train_log,
                            scoring="neg_root_mean_squared_error",
                            cv=cv, n_jobs=-1).mean()
    return rmse

study = optuna.create_study(direction="minimize",
                            sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=40, timeout=60*25)   # 40 trials or 25 min

print("Optuna best RMSE:", study.best_value)
print("Best params:",      study.best_params)

best_xgb = xgb.XGBRegressor(**study.best_params)
best_xgb.fit(X_train_sel, y_train_log)
# Out:
# [I 2025-04-29 20:58:34,906] A new study created in memory with name: no-name-10565027-6b01-4231-a2aa-ba1766c1f4cd
# [I 2025-04-29 20:58:49,504] Trial 0 finished with value: 0.20226870650739395 and parameters: {'n_estimators': 350, 'max_depth': 10, 'lr': 0.06504856968981275, 'subsample': 0.7993292420985183, 'colsample': 0.5780093202212182, 'l2': 0.004207053950287938}. Best is trial 0 with value: 0.20226870650739395.
# [I 2025-04-29 20:58:57,522] Trial 1 finished with value: 0.21543764139997842 and parameters: {'n_estimators': 223, 'max_depth': 10, 'lr': 0.030834348179355788, 'subsample': 0.8540362888980227, 'colsample': 0.5102922471479012, 'l2': 7.579479953348009}. Best is trial 0 with value: 0.20226870650739395.
# ...

# %% [markdown]
# ## 4. Ensemble of Tree Ensembles

# %% [markdown]
# ### Simple Averaging

# %%
# Simple Averaging

# Assume best_rf and best_xgb are your tuned Random Forest and XGBoost models, respectively.
# They are already trained on the training set with the selected features.

# Generate predictions on the validation set
y_val_pred_rf = rf_model.predict(X_val_sel)
y_val_pred_xgb = xgb_model.predict(X_val_sel)

# Simple average of the predictions
y_val_pred_avg = (y_val_pred_rf + y_val_pred_xgb) / 2.0

# Compute RMSE on the log scale
rmse_avg_val = np.sqrt(mean_squared_error(y_val_log, y_val_pred_avg))
print(f"Simple Averaging Validation RMSE (log-scale): {rmse_avg_val:.3f}")

# Similarly, you can average predictions on the test set:
y_test_pred_rf = rf_model.predict(X_test_sel)
y_test_pred_xgb = xgb_model.predict(X_test_sel)
y_test_pred_avg = (y_test_pred_rf + y_test_pred_xgb) / 2.0
rmse_avg_test = np.sqrt(mean_squared_error(y_test_log, y_test_pred_avg))
print(f"Simple Averaging Test RMSE (log-scale): {rmse_avg_test:.3f}")
# Out:
# Simple Averaging Validation RMSE (log-scale): 0.207
# Simple Averaging Test RMSE (log-scale): 0.204

# %%
# 3.1  Error distribution compared to the best single model
best_single_name = "XGB"           
best_val_pred    = y_val_pred_xgb  

df_err = pd.DataFrame({
    "Single best": y_val_log - best_val_pred,
    "Simple avg" : y_val_log - y_val_pred_avg
})
sns.kdeplot(data=df_err, fill=True, common_norm=False)
plt.axvline(0, ls='--', c='k', lw=.7)
plt.title("Validation residual distribution\n(closer to 0 = better)")
plt.xlabel("Residual (log £)")
plt.show()

# %% [markdown]
# Take-away: even though XGB alone is already strong, combining it with the RF shaves off a bit of random error – the density plot visualises that gain more intuitively than looking at a third-decimal RMSE change.

# %%
resids_val = pd.DataFrame({
    "RF" : y_val_log - y_val_pred_rf,
    "XGB": y_val_log - y_val_pred_xgb
})
sns.heatmap(resids_val.corr(), annot=True, vmin=-1, vmax=1, cmap="coolwarm")
plt.title("Residual correlation between base learners")
plt.show()

# %% [markdown]
# “The residual correlation between RF and XGB is ρ ≈ 0.85 (< 1), indicating partially complementary error patterns; hence averaging/stacking can reduce variance.”

# %% [markdown]
# ### Stacking Ensemble

# %%
# Stacking Ensemble

# Define the base estimators using your tuned models.
# We label each estimator for reference.
estimators = [
    ('rf', rf_model),
    ('xgb', xgb_model),
    ('lgb', lgb_model)
]

# Create a StackingRegressor with a LinearRegression meta-learner.
# We use KFold cross-validation with 5 folds for stacking.
stacking_regressor = StackingRegressor(
    estimators=estimators,
    final_estimator=LinearRegression(),
    cv=KFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=-1  # use all available cores
)

# Fit the stacking ensemble on the selected training features.
stacking_regressor.fit(X_train_sel, y_train_log)

# Predict on the validation set.
y_val_pred_stack = stacking_regressor.predict(X_val_sel)

# Calculate metrics on the validation set.
mse_val = mean_squared_error(y_val_log, y_val_pred_stack)
mae_val = mean_absolute_error(y_val_log, y_val_pred_stack)
r2_val  = r2_score(y_val_log, y_val_pred_stack)

print("Stacking Ensemble Validation Metrics (log-scale):")
print(f"  MSE: {mse_val:.3f}")
print(f"  RMSE: {np.sqrt(mse_val):.3f}")
print(f"  MAE: {mae_val:.3f}")
print(f"  R²: {r2_val:.3f}")

# Calculate RMSE on validation set.
rmse_stack_val = np.sqrt(mean_squared_error(y_val_log, y_val_pred_stack))
print(f"Stacking Ensemble Validation RMSE (log-scale): {rmse_stack_val:.3f}")

# Evaluate on the test set.
y_test_pred_stack = stacking_regressor.predict(X_test_sel)
rmse_stack_test = np.sqrt(mean_squared_error(y_test_log, y_test_pred_stack))
print(f"Stacking Ensemble Test RMSE (log-scale): {rmse_stack_test:.3f}")

# Calculate metrics on the test set.
mse_test = mean_squared_error(y_test_log, y_test_pred_stack)
mae_test = mean_absolute_error(y_test_log, y_test_pred_stack)
r2_test  = r2_score(y_test_log, y_test_pred_stack)

print("\nStacking Ensemble Test Metrics (log-scale):")
print(f"  MSE: {mse_test:.3f}")
print(f"  RMSE: {np.sqrt(mse_test):.3f}")
print(f"  MAE: {mae_test:.3f}")
print(f"  R²: {r2_test:.3f}")
# Out:
# Stacking Ensemble Validation Metrics (log-scale):
#   MSE: 0.040
#   RMSE: 0.199
#   MAE: 0.131
#   R²: 0.946
# Stacking Ensemble Validation RMSE (log-scale): 0.199
# Stacking Ensemble Test RMSE (log-scale): 0.196
#
# Stacking Ensemble Test Metrics (log-scale):
#   MSE: 0.039
#   RMSE: 0.196
#   MAE: 0.129
#   R²: 0.947

# %% [markdown]
# Stacking Ensemble Validation Metrics (log-scale):
#   MSE: 0.040
#   RMSE: 0.199
#   MAE: 0.131
#   R²: 0.946
# Stacking Ensemble Validation RMSE (log-scale): 0.199
# Stacking Ensemble Test RMSE (log-scale): 0.196
#
# Stacking Ensemble Test Metrics (log-scale):
#   MSE: 0.039
#   RMSE: 0.196
#   MAE: 0.129
#   R²: 0.947

# %%
# ──────────────────────────────────────────────────────────────────────────
# 1.  Build out-of-fold (OOF) predictions for each base learner
#     + create an EXTRA column = simple average(RF, XGB, LGB)
# ──────────────────────────────────────────────────────────────────────────
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from matplotlib.ticker import FuncFormatter

RANDOM_STATE = 42
cv_outer = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=RANDOM_STATE
)

# bin the target so StratifiedKFold makes sense on a regression problem
bins = pd.qcut(y_train_log, 10, labels=False)

def oof(model, name):
    """Return a pandas Series of out-of-fold predictions (aligned to y)."""
    preds = cross_val_predict(
        model, X_train_sel, y_train_log,
        cv=cv_outer.split(X_train_sel, bins),
        n_jobs=-1,
        method="predict"
    )
    return pd.Series(preds, name=name, index=y_train_log.index)

print("⏳  Generating OOF predictions …")
oof_rf  = oof(rf_model,  "RF")
oof_xgb = oof(xgb_model, "XGB")
oof_lgb = oof(lgb_model, "LGB")

# META-DATASET:   3 OOF columns  +  their simple average
meta_X = pd.concat([oof_rf, oof_xgb, oof_lgb], axis=1)
meta_X["AVG"] = meta_X.mean(axis=1)          # <- suggestion 3
meta_y = y_train_log

# ──────────────────────────────────────────────────────────────────────────
# 2.  Train the meta-learner  (ridge automatically tunes L2 via CV)
# ──────────────────────────────────────────────────────────────────────────
meta = RidgeCV(alphas=[0.01, 0.1, 1.0, 10.0])
meta.fit(meta_X, meta_y)

print("\n🏋️  Meta-learner weights (Ridge coefficients)")
for col, w in zip(meta_X.columns, meta.coef_):
    print(f"  {col:3s} : {w:+.3f}")

# ──────────────────────────────────────────────────────────────────────────
# 3.  Make STACKING predictions on val / test
#     (feed the BASE learners’ *full-fit* predictions into the meta model)
# ──────────────────────────────────────────────────────────────────────────
def stack_predict(X):
    """Helper – run base models, build matrix [RF, XGB, LGB, AVG] and meta-predict."""
    preds = np.column_stack([
        rf_model .predict(X),
        xgb_model.predict(X),
        lgb_model.predict(X)
    ])
    avg   = preds.mean(axis=1, keepdims=True)
    preds = np.hstack([preds, avg])
    return meta.predict(preds)

y_val_pred_stack  = stack_predict(X_val_sel)
y_test_pred_stack = stack_predict(X_test_sel)

def metrics(y_true, y_pred, name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    print(f"{name:<5} RMSE(log£)={rmse:.3f}  MAE={mae:.3f}  R²={r2:.3f}")

print("\n📊  Stacking performance")
metrics(y_val_log , y_val_pred_stack , "VAL")
metrics(y_test_log, y_test_pred_stack, "TEST")
# Out:
# ⏳  Generating OOF predictions …
#
# 🏋️  Meta-learner weights (Ridge coefficients)
#   RF  : -0.220
#   XGB : +0.635
#   LGB : +0.337
#   AVG : +0.250
#
# 📊  Stacking performance
# VAL   RMSE(log£)=0.199  MAE=0.131  R²=0.946
# TEST  RMSE(log£)=0.196  MAE=0.129  R²=0.947

# %%
# ──────────────────────────────────────────────────────────────────────────
# 4.  Diagnostics visualisations
#      4a) meta-weights bar-plot
#      4b) residual density overlay   (val set)
# ──────────────────────────────────────────────────────────────────────────
sns.set_style("whitegrid")

# 4a – weight bar
plt.figure(figsize=(6,4))
plt.bar(meta_X.columns, meta.coef_, color="steelblue")
plt.title("Meta-learner weights")
plt.ylabel("Coefficient"); plt.xlabel("Meta-feature")
plt.axhline(0, lw=.8, c='k'); plt.tight_layout()

# 4b – residual density
# predictions → wrap in a Series using the *validation* index
val_pred_xgb = pd.Series(y_val_pred_xgb, index=y_val_log.index, name="xgb")

val_res_single = y_val_log - val_pred_xgb            # assume XGB was single-best
val_res_stack  = y_val_log - y_val_pred_stack
plt.figure(figsize=(6,4))
sns.kdeplot(val_res_single, fill=True, color="seagreen", alpha=.4, label="Single best (XGB)")
sns.kdeplot(val_res_stack , fill=True, color="coral",    alpha=.4, label="Stacked")
plt.axvline(0, ls='--', c='k')
plt.title("Validation residual distribution (closer to 0 = better)")
plt.xlabel("Residual (log £)"); plt.legend(); plt.tight_layout()

plt.show()

# %% [markdown]
# A ridge-regularised stacking ensemble that combines RF, XGB, LGB and their simple average reduced validation RMSE from 0.211 to 0.199 (-6 %) and test RMSE from 0.209 to 0.196 (-6 %). The meta-learner automatically down-weighted the highly correlated Random-Forest (+ve XGB 0.635, LGB 0.337, ­ve RF -0.220), confirming that diversity rather than sheer model count drives the gain.

# %%
# ── 1 ▸ bar-chart of improvements ───────────────────────────────
scores = pd.DataFrame({'XGB': [0.211, 0.209],
                       'Avg': [0.205, 0.204],
                       'Stack': [0.199, 0.196]},
                      index=['Val', 'Test']).T
scores.plot(kind='barh', figsize=(6,2.5), color=['tab:cyan','tab:orange'])
plt.title('RMSE (log £) – lower is better'); plt.xlabel('RMSE'); plt.tight_layout()

# %% [markdown]
# ## 5. Feature Importance

# %% [markdown]
# #### Permutation Importance

# %%
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import numpy as np

# Assume best_rf is your trained RandomForestRegressor on the selected features.
# Compute permutation importance on the validation set.
perm_importance = permutation_importance(
    xgb_model, X_val_sel, y_val_log, scoring="neg_mean_squared_error", n_repeats=10, random_state=42, n_jobs=-1
)

# Extract the importance values and standard deviations.
importances = perm_importance.importances_mean
stds = perm_importance.importances_std

# Create a DataFrame for better visualization.
perm_df = pd.DataFrame({
    'feature': X_val_sel.columns,
    'importance': importances,
    'std': stds
}).sort_values(by='importance', ascending=False)

print("Permutation Importance: XGB model")
print(perm_df)

# Plot the permutation importances.
plt.figure(figsize=(10, 6))
plt.barh(perm_df['feature'], perm_df['importance'], xerr=perm_df['std'], align='center')
plt.gca().invert_yaxis()  # highest importance on top
plt.xlabel("Decrease in Performance (neg MSE)")
plt.title("Permutation Importance: XGB Model")
plt.show()
# Out:
# Permutation Importance: XGB model
#                     feature  importance       std
# 13      standard_make_model    0.400074  0.001763
# 11  mileage_age_interaction    0.131033  0.000425
# 7                   mileage    0.073582  0.000625
# 8      year_of_registration    0.066223  0.000434
# 14          is_luxury_brand    0.057722  0.000454
# 9               vehicle_age    0.052534  0.000442
# 3       body_type_Hatchback    0.027670  0.000420
# 5             body_type_SUV    0.016013  0.000113
# 1          fuel_type_Petrol    0.010429  0.000109
# 10         mileage_per_year    0.006292  0.000303
# 6          body_type_Saloon    0.003767  0.000154
# 0          fuel_type_Hybrid    0.003498  0.000096
# 2           body_type_Coupe    0.003132  0.000052
# 4             body_type_MPV    0.002914  0.000053
# 12        listing_month_day    0.001498  0.000192

# %%
print("  Computing permutation importance on StackingRegressor …")
perm = permutation_importance(
    stacking_regressor,               # final model
    X_val_sel, y_val_log,
    n_repeats=15,
    scoring="neg_mean_squared_error",
    random_state=42,
    n_jobs=-1,
)

perm_df = (
    pd.DataFrame({"feature": X_val_sel.columns,
                  "imp"     : perm.importances_mean,
                  "std"     : perm.importances_std})
      .sort_values("imp", ascending=False)
      .head(20)                         # top-20 is plenty
)

plt.figure(figsize=(7,6))
sns.barplot(data=perm_df, y="feature", x="imp", xerr=perm_df["std"],
            color="steelblue")
plt.xlabel("↓  Increase in validation MSE when shuffled (log-scale)")
plt.ylabel("")
plt.title("Permutation importance – final stacked ensemble")
plt.tight_layout(); plt.show()
# Out:
#   Computing permutation importance on StackingRegressor …

# %% [markdown]
# Permutation-importance on the stacked ensemble (Fig. X) shows that target-encoded standard_make_model is by far the most critical variable: shuffling it raises validation MSE by 0.42 (≈ +20 % RMSE). Wear-related variables (mileage_age_interaction, mileage, vehicle_age) together account for another ≈ 30 % of error reduction, confirming domain expectations. All remaining dummy variables contribute < 0.05, indicating diminishing returns

# %% [markdown]
# ### SHAP

# %%
import shap
shap.initjs()

# Create a TreeExplainer for your trained model.
# For tree ensembles, TreeExplainer is optimized for performance.
explainer = shap.TreeExplainer(xgb_model, feature_perturbation="tree_path_dependent")

# To reduce computation time on large datasets, sample a subset.
X_val_sample = X_val_sel.sample(1000, random_state=42)

# Compute SHAP values for the sampled data.
shap_values = explainer.shap_values(X_val_sample)

# Global interpretation: SHAP summary plot.
shap.summary_plot(shap_values, X_val_sample, feature_names=X_val_sel.columns)

# Alternatively, you can generate a bar plot summarizing mean(|SHAP|) per feature.
shap.summary_plot(shap_values, X_val_sample, plot_type="bar", feature_names=X_val_sel.columns)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# ------------------------------------------------------------------------------
# 0) Sample
X_val_sample = X_val_sel.sample(3000, random_state=42)

# 1) Explainer & SHAP values -----------------------------------------------
explainer   = shap.TreeExplainer(xgb_model, feature_perturbation="tree_path_dependent")
shap_values = explainer.shap_values(X_val_sample)     # 15-20 s for 3k rows

# 2) Global summary plots ---------------------------------------------------
shap.summary_plot(shap_values, X_val_sample, feature_names=X_val_sel.columns,
                  max_display=15, show=False)
plt.title("SHAP summary – top 15 (XGB)"); plt.tight_layout(); plt.show()

shap.summary_plot(shap_values, X_val_sample, feature_names=X_val_sel.columns,
                  plot_type="bar", max_display=15, show=False)
plt.title("Mean(|SHAP|) – global magnitude"); plt.tight_layout(); plt.show()

# 3) Dependence plot for the key interaction --------------------------------
shap.dependence_plot("mileage_age_interaction", shap_values, X_val_sample,
                     interaction_index="vehicle_age", show=False)
plt.title("Dependence: mileage × age interaction")
plt.tight_layout(); plt.show()

# 4) Local explanation ------------------------------------------------------
idx = 0   # first row
shap.force_plot(explainer.expected_value, shap_values[idx, :],
                X_val_sample.iloc[idx, :], matplotlib=True)

# %% [markdown]
# A sensitivity check with 3 k vs 1 k rows produced identical top-10 ranking (see Appendix X), so we report the lighter 1 k-row plot for clarity.”

# %% [markdown]
# ## 6. SHAP/PDP Model Explanations

# %%
# top numeric features from your SHAP bar
num_feats   = ['mileage', 'mileage_age_interaction',
               'vehicle_age', 'year_of_registration']
bin_feats   = ['is_luxury_brand']      # treat separately

# strongest interaction: mileage_age_interaction × vehicle_age
pair_feats  = [('mileage_age_interaction', 'vehicle_age')]

# %%
# Generate a PDP 
features_to_plot = ['mileage', 'standard_make_model', 'is_luxury_brand']   

# For a trained model (e.g., best_rf) and data (e.g., X_train_selected)
fig, ax = plt.subplots(figsize=(8, 6))
PartialDependenceDisplay.from_estimator(rf_model, X_train_sel, features_to_plot, ax=ax, grid_resolution=50)
plt.title("Partial Dependence Plot for 'mileage'")
plt.show()

# %% [markdown]
# Feature Influence:
# Each plot demonstrates how changing one feature alone (mileage, brand-model combo, or the luxury brand flag) shifts the log-price prediction when other features are averaged out (marginalized).
#
# Model Validation:
#
# The strong negative slope for mileage confirms the model’s alignment with domain knowledge.
#
# A big jump for is_luxury_brand supports that premium branding significantly boosts estimated price.
#
# The steep climb for certain brand–model combos shows that some makes/models are predicted to have higher log-prices relative to others.
#
# Further Analysis:
# You might produce PDPs for other high-impact features (e.g., vehicle_age or mileage_age_interaction) to confirm that your model is capturing key relationships. Also, compare these PDP insights with your SHAP analyses to see if the top features match and the directional effects are consistent.

# %%
fig, ax = plt.subplots(figsize=(10,8), constrained_layout=True)

PartialDependenceDisplay.from_estimator(
    rf_model,                  # Your trained model
    X_test_sel,               # Test set with selected features (must be a DataFrame)
    features=['mileage', 'mileage_age_interaction', 'is_luxury_brand', 'vehicle_age'],  # Continuous features to plot PDPs for
    kind='both',              # Show average PDP as well as individual ICE curves
    subsample=1000,           # Use a random subsample of 1000 test instances for ICE plots (adjust based on your dataset size)
    grid_resolution=30,       # Number of points in the grid for plotting curves
    n_jobs=-1,                # Use all CPU cores for faster computation
    random_state=42,          # For reproducibility of subsampling
    ax=ax,                    # Use the specified axes object
    n_cols=2,                 # Arrange the plots in 2 columns
    pd_line_kw={'color': 'red'}  # Customize the PDP line appearance
)

plt.suptitle("Partial Dependence Plots for Mileage and Mileage-Age Interaction", fontsize=16)
plt.show()

# %% [markdown]
# standard_make_model (0.2638 importance):
# This is by far the most influential feature. The permutation importance value indicates that shuffling this feature results in the largest drop in model performance. That tells you that the combination of the car’s make and model is a critical driver of price, which makes intuitive sense for car sales.
#
# mileage_age_interaction (0.0868 importance):
# The high importance for this engineered feature suggests that the interaction between mileage and vehicle age contains valuable predictive information. In real-world terms, a high product of mileage and age typically implies that a car might have more wear, which heavily impacts its price.
#
# is_luxury_brand (0.0545 importance):
# This feature shows that whether a car is considered a luxury brand also significantly influences predictions. Luxury vehicles tend to command higher prices; hence, this feature helps the model differentiate between premium and non-premium vehicles.
#
# year_of_registration (0.0483) and vehicle_age (0.0444):
# These features together capture the age and registration characteristics of a vehicle. Their moderately high importance indicates that more recent (or properly registered) cars are generally valued higher.
#
# mileage (0.0316) and mileage_per_year (0.00516):
# While mileage is important on its own, notice that the engineered feature mileage_age_interaction carries more weight, suggesting that the context in which mileage appears (i.e., the car’s age) is crucial for understanding its true impact on price.
#
# The remaining features (categorical ones like fuel_type and body_type variants, listing_month_day):
# These features have lower permutation importance, which means that, while they play a role, their impact on model performance is less than that of the top features.

# %%
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt

num_feats = ['mileage', 'mileage_age_interaction',
             'vehicle_age', 'year_of_registration']

fig, ax = plt.subplots(len(num_feats)//2, 2, figsize=(10, 8), sharey=False)

PartialDependenceDisplay.from_estimator(
    xgb_model,
    X_val_sel,
    features=num_feats,
    kind='both',              # PDP + ICE
    subsample=1500,
    grid_resolution=40,
    random_state=42,
    ax=ax.ravel(),

    # --- styling --------------------------
    pd_line_kw={'color': 'crimson', 'linewidth': 2},     # PDP curve
    ice_lines_kw={'color': 'steelblue',
                  'alpha': .08,
                  'linewidth': .5},                      # ICE traces
    # NOTE: we do NOT pass `line_kw` – avoids clashes
)

fig.suptitle("1-D PDP + ICE – numeric drivers of log-price", y=1.02)
plt.tight_layout(); plt.show()

# %%
# ── 2-D surface for key interaction ────────────────────────────
fig = plt.figure(figsize=(6,5))
PartialDependenceDisplay.from_estimator(
    xgb_model,
    X_val_sel,
    features=pair_feats,             # list of tuple(s)
    kind='average',                  # surface = average
    grid_resolution=30,
)
plt.gca().set_title("2-D PDP – mileage × vehicle-age synergy")
plt.tight_layout(); plt.show()

# %% [markdown]
# “Figure X illustrates 1-D partial-dependence and ICE traces for the four most important numerical drivers. The average PDP (red) confirms the expected negative elasticity of price with respect to mileage and its interaction with age. ICE dispersion widens beyond ≈10 (log-km), signalling strong interactions – later verified in the 2-D PDP (Figure Y), where a steep ridge appears for mileage×age > 12.

# %% [markdown]
# ## 7. Dimensionality Reduction (Linear)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# --- Step 1. Optionally, Scale Your Data (if not already scaled)
# PCA is sensitive to the scale of the features. If your advanced pipeline hasn't scaled the data,
# we scale it here. (For tree ensembles, scaling isn't usually necessary, but PCA is a linear method.)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_final)
X_val_scaled   = scaler.transform(X_val_final)
X_test_scaled  = scaler.transform(X_test_final)

# Convert back to DataFrame for interpretability
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_final.columns, index=X_train_final.index)
X_val_scaled   = pd.DataFrame(X_val_scaled, columns=X_train_final.columns, index=X_val_final.index)
X_test_scaled  = pd.DataFrame(X_test_scaled, columns=X_train_final.columns, index=X_test_final.index)

# --- Step 2. Fit PCA on the Training Data
# Set n_components to the number of features (or a high enough value) so that you can examine explained variance.
pca = PCA(n_components=X_train_scaled.shape[1], random_state=42)
pca.fit(X_train_scaled)

# --- Step 3. Examine the Explained Variance
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

plt.figure(figsize=(8, 6))
plt.plot(np.arange(1, len(cumulative_variance)+1), cumulative_variance, marker='o', color='blue')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Explained Variance")
plt.axhline(y=0.90, color='red', linestyle='--', label="90% Explained Variance")
plt.legend()
plt.grid(True)
plt.show()

# From the plot, decide how many components to retain.
# For example, if 90% of the variance is explained by the first 10 components, then use n_components=10.
n_components = np.argmax(cumulative_variance >= 0.90) + 1
print(f"Number of components explaining at least 90% of variance: {n_components}")

# --- Step 4. Transform Your Data Using the Selected Number of Components
pca_final = PCA(n_components=n_components, random_state=42)
X_train_pca = pca_final.fit_transform(X_train_scaled)
X_val_pca   = pca_final.transform(X_val_scaled)
X_test_pca  = pca_final.transform(X_test_scaled)

# Convert transformed arrays to DataFrame with meaningful column names.
pca_columns = [f'PC{i+1}' for i in range(n_components)]
X_train_pca_df = pd.DataFrame(X_train_pca, columns=pca_columns, index=X_train_scaled.index)
X_val_pca_df   = pd.DataFrame(X_val_pca, columns=pca_columns, index=X_val_scaled.index)
X_test_pca_df  = pd.DataFrame(X_test_pca, columns=pca_columns, index=X_test_scaled.index)

# --- Step 5. Optional: Evaluate PCA by Training a Simple Model
# This helps assess if retaining fewer components still supports good performance.
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train_pca_df, y_train_log)  # using log-transformed target if applicable
y_val_pred_lr = lr.predict(X_val_pca_df)
rmse_lr = np.sqrt(mean_squared_error(y_val_log, y_val_pred_lr))
r2_lr = lr.score(X_val_pca_df, y_val_log)
print(f"Linear Regression on PCA components -> Validation RMSE: {rmse_lr:.3f}, R²: {r2_lr:.3f}")

# In your final model, you would use these reduced-dimension features as your input for further modeling.
# Out:
# Number of components explaining at least 90% of variance: 24
# Linear Regression on PCA components -> Validation RMSE: 0.440, R²: 0.736

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# ── 1.  Select numeric columns only ───────────────────────────────────────────
num_cols = X_train_final.select_dtypes(float).columns

# ── 2.  Build a pipeline: scale → PCA (90 %) ──────────────────────────────────
pca_pipeline = Pipeline([
    ("scale", StandardScaler()),
    ("pca",   PCA(n_components=0.90, svd_solver="full", random_state=42))  # keep PCs until 90 %
]).fit(X_train_final[num_cols])

X_train_pca = pca_pipeline.transform(X_train_final[num_cols])
X_val_pca   = pca_pipeline.transform(X_val_final[num_cols])
X_test_pca  = pca_pipeline.transform(X_test_final[num_cols])

k = pca_pipeline.named_steps["pca"].n_components_
print(f"✔  {k} principal components retained")

# ── 3.  Scree / cumulative variance plot ─────────────────────────────────────
cum_var = np.cumsum(pca_pipeline.named_steps["pca"].explained_variance_ratio_)
plt.figure(figsize=(7,5))
plt.plot(np.arange(1, len(cum_var)+1), cum_var, marker="o")
plt.axhline(0.90, ls="--", c="red"); plt.text(k, 0.91, f"90 % at {k} PCs")
plt.xlabel("Number of PCs"); plt.ylabel("Cumulative explained variance")
plt.title("PCA – explained variance curve"); plt.grid(True); plt.show()

# ── 4.  Quick linear-regression sanity check ─────────────────────────────────
lr = LinearRegression().fit(X_train_pca, y_train_log)
y_val_pred = lr.predict(X_val_pca)
rmse = np.sqrt(mean_squared_error(y_val_log, y_val_pred))
r2   = r2_score(y_val_log, y_val_pred)
print(f"Linear model on PCs →  RMSE={rmse:.3f},  R²={r2:.3f}")

# ── 5.  (Optional) loading matrix for interpretation ─────────────────────────
load_df = pd.DataFrame(
    pca_pipeline.named_steps["pca"].components_.T,
    index=num_cols,
    columns=[f"PC{i+1}" for i in range(k)]
)
top_contrib = load_df.iloc[:,0].abs().sort_values(ascending=False).head(10)
print("\nTop features in PC-1:\n", top_contrib)
# Out:
# ✔  22 principal components retained
# Linear model on PCs →  RMSE=0.549,  R²=0.589
#
# Top features in PC-1:
#  fuel_type_Petrol        0.468519
# body_type_Hatchback     0.468094
# fuel_type_Diesel        0.430969
# standard_make_model     0.418983
# body_type_SUV           0.348279
# body_type_Saloon        0.141232
# standard_colour_Red     0.113554
# standard_colour_Grey    0.102703
# body_type_Estate        0.089367
# fuel_type_Hybrid        0.085322
# Name: PC1, dtype: float64

# %%
# -- loading matrix for the first 3 PCs
loadings = pd.DataFrame(pca.components_[:3].T,
                        index=X_train_scaled.columns,
                        columns=['PC1','PC2','PC3'])

# show biggest absolute weights per PC
for pc in loadings:
    print(f"\nTop 8 loadings for {pc}")
    display(loadings[pc].abs().sort_values(ascending=False).head(8))
# Out:
# Top 8 loadings for PC1
# mileage                    0.450972
# mileage_age_interaction    0.441051
# year_of_registration       0.406997
# vehicle_age                0.392798
# vehicle_condition          0.370362
# standard_make_model        0.179624
# body_type_SUV              0.169907
# mileage_per_year           0.144085
# Name: PC1, dtype: float64
# Top 8 loadings for PC2
# fuel_type_Petrol       0.439946
# fuel_type_Diesel       0.431564
# body_type_Hatchback    0.415658
# standard_make_model    0.388638
# is_luxury_brand        0.357128
# body_type_SUV          0.233315
# body_type_Saloon       0.186979
# mileage_per_year       0.118623
# Name: PC2, dtype: float64
# Top 8 loadings for PC3
# crossover_car_and_van                  0.654438
# body_type_Utility Vehicles             0.613293
# body_type_Luxury/Passenger Vehicles    0.194002
# mileage_per_year                       0.184997
# vehicle_condition                      0.146862
# ...

# %%
# --- 2. Loading barplot for PC-1 ---
pc1_load = pd.Series(pca.components_[0], index=X_train_scaled.columns)
(pc1_load.abs()
          .sort_values(ascending=False)
          .head(10)
          .plot(kind='barh', figsize=(6,4), color='slateblue'))
plt.gca().invert_yaxis()
plt.xlabel('Absolute loading')
plt.title('Top features contributing to PC-1')
plt.tight_layout()

# %% [markdown]
# Using PCA we compressed the 35 engineered features into 24 orthogonal components that still explain 90 % of the variance. A simple linear regression on these PCs achieves RMSE 0.440 (log-scale), outperforming the raw-linear baseline but remaining below tree ensembles. The first principal axis is largely driven by petrol-/diesel fuel type and hatchback/SUV body style, indicating that segment & fuel choice explain most variance in car price among the engineered variables

# %% [markdown]
# PCA shows that most price variance is tied to segment/fuel and age variables; the remaining PCs add diminishing returns, so 24-D captures the gist while halving feature dimensionality.”

# %% [markdown]
# ## 8. Dimensionality Reduction (Non-Linear)

# %%
import numpy as np
import pandas as pd
from sklearn.manifold import Isomap
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# 1. Subsample landmarks
n_landmarks = 1000
landmark_idx = np.random.RandomState(42).choice(
    X_train_scaled.shape[0], n_landmarks, replace=False
)
X_landmarks = X_train_scaled.iloc[landmark_idx]

# 2. Fit Isomap on landmarks
iso = Isomap(n_neighbors=10, n_components=2)
X_iso_land = iso.fit_transform(X_landmarks)

# 3. Build a KNN on the landmarks in original space
knn = NearestNeighbors(n_neighbors=5).fit(X_landmarks)

# 4. For any new point x, approximate its Isomap embedding by averaging
#    the embeddings of its nearest landmarks.
def landmark_embedding(X_new):
    dists, idxs = knn.kneighbors(X_new)
    return np.stack([X_iso_land[i].mean(axis=0) for i in idxs])

# 5. Embed train/val/test
X_iso_train = landmark_embedding(X_train_scaled)
X_iso_val   = landmark_embedding(X_val_scaled)
X_iso_test  = landmark_embedding(X_test_scaled)

# 6. Quick plot of train embedding
plt.figure(figsize=(6,5))
plt.scatter(X_iso_train[:,0], X_iso_train[:,1],
            c=y_train_log, cmap='viridis', s=6, alpha=0.7)
plt.title("Landmark‑Isomap (1k) embedding")
plt.colorbar(label='log(price)')
plt.show()

# %% [markdown]
# The Isomap map suggests a continuous price axis from lower-left to upper-right and isolates a compact ‘luxury-supercar’ island (x ≈ 30, y ≈ 2). This supports the engineered features (standard_make_model, is_luxury_brand) and could drive an interactive pricing explorer for stakeholders

# %%
##############################################################################
#  0 ▸ SET-UP & DATA SAMPLING
##############################################################################
import numpy as np, matplotlib.pyplot as plt, seaborn as sns, pathlib
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold      import MDS, Isomap, TSNE
from mpl_toolkits.mplot3d  import Axes3D        # noqa: F401 – activates 3-D
sns.set_style("whitegrid")

# ---------- (0.1)  choose a manageable subsample --------------------------------
N_SAMP  = 30_000                 # ← tweak: 30 k rows ≈ 10–20 s per method
rng     = np.random.RandomState(42)

sample_idx = rng.choice(X_train_final.shape[0], N_SAMP, replace=False)
X_small    = X_train_final.iloc[sample_idx]
t_colour   = y_train_log.iloc[sample_idx]       # colour by log-price

# ---------- (0.2)  scale features column-wise  ----------------------------------
Xs = StandardScaler().fit_transform(X_small)    # ndarray (N_SAMP × n_feat)

##############################################################################
#  1 ▸ EMBEDDINGS (2-D) – linear & non-linear
##############################################################################
embeddings = {
    "PCA (linear)"          : PCA(n_components=2, random_state=rng).fit_transform(Xs),

    "Classical MDS (global)": MDS(n_components=2, metric=True, dissimilarity="euclidean",
                                  random_state=rng, n_init=1, max_iter=300).fit_transform(Xs),

    "Isomap (geodesic)"     : Isomap(n_neighbors=10, n_components=2).fit_transform(Xs),

    "t-SNE (local)"         : TSNE(n_components=2, perplexity=30, learning_rate="auto",
                                   init="pca", random_state=rng, n_iter=1_000).fit_transform(Xs),
}

##############################################################################
#  2 ▸  QUICK 3-D REFERENCE  (optional – skip if >2 features is huge)
##############################################################################
fig3d = plt.figure(figsize=(5, 4))
ax3d  = fig3d.add_subplot(111, projection="3d")
ax3d.scatter(X_small.iloc[:, 0], X_small.iloc[:, 1], X_small.iloc[:, 2],
             c=t_colour, cmap="viridis", s=6, alpha=.7)
ax3d.set_title("Car-feature space – first 3 dimensions")
ax3d.set_axis_off()
plt.tight_layout()
plt.show()

##############################################################################
#  3 ▸  INDIVIDUAL 2-D PANELS
##############################################################################
def scatter_2d(ax, emb, title):
    sc = ax.scatter(emb[:, 0], emb[:, 1], c=t_colour,
                    cmap="viridis", s=6, alpha=0.7)
    ax.set_title(title, fontsize=11)
    ax.set_axis_off()
    return sc

for name, emb in embeddings.items():
    fig, ax = plt.subplots(figsize=(4.2, 4))
    scatter_2d(ax, emb, name)
    fig.suptitle("Projection of car features", fontsize=12, y=1.02)
    plt.tight_layout()
    plt.show()

##############################################################################
#  4 ▸  COMPOSITE 5-PANEL FIGURE  (3-D ref  + 4 projections)
##############################################################################
from matplotlib.gridspec import GridSpec
fig = plt.figure(figsize=(21, 4.5))
gs  = GridSpec(1, 5, figure=fig, wspace=0.05)

# 4a –  3-D reference
ax0 = fig.add_subplot(gs[0], projection="3d")
ax0.scatter(X_small.iloc[:, 0], X_small.iloc[:, 1], X_small.iloc[:, 2],
            c=t_colour, cmap="viridis", s=6, alpha=.7)
ax0.set_title("Raw feature space (3-D slice)")
ax0.set_axis_off()

# 4b –  2-D DR panels
for gspec, (title, emb) in zip(list(gs)[1:], embeddings.items()):
    ax = fig.add_subplot(gspec)
    scatter_2d(ax, emb, title)

# shared colour-bar
cbar = fig.colorbar(plt.cm.ScalarMappable(cmap="viridis"),
                    ax=fig.axes, location="right", fraction=.03, pad=0.02)
cbar.set_label("log(price)", rotation=270, labelpad=15)

fig.suptitle("Linear vs non-linear DR on car-price feature space", y=1.05, fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Linear methods (PCA, classical MDS) are inadequate for highly curved manifolds.
#
# Isomap recovers the latent 2-D structure because it explicitly uses geodesic distances.
#
# t-SNE is great for visualising local clusters but distorts the global map – you cannot measure “far” vs “very far” anymore.

# %% [markdown]
# ## 9. Polynomial Regression

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import RidgeCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# --------------------------- 1. choose numeric base variables
base_numeric = ["mileage", "vehicle_age", "mileage_per_year"]

# --------------------------- 2. build pipeline
pipe_poly = Pipeline([
    ("selector", ColumnTransformer(
        [("num", "passthrough", base_numeric)], remainder="drop")),
    ("scaler",   StandardScaler()),                     # essential for Ridge
    ("poly",     PolynomialFeatures(degree= 2, include_bias=False)),
    ("ridge",    RidgeCV(alphas=np.logspace(-3, 3, 9))) # CV picks best λ
])

# --------------------------- 3. cross-validated scores
cv = ShuffleSplit(n_splits=5, test_size=.2, random_state=42)
rmse = np.sqrt(-cross_val_score(pipe_poly, X_train_final, y_train_log,
                                scoring="neg_mean_squared_error", cv=cv))
print(f"Poly-Ridge (deg=2)  CV-RMSE(log£):  {rmse.mean():.3f} ± {rmse.std():.3f}")

# --------------------------- 4. refit on full train and evaluate on val
pipe_poly.fit(X_train_final, y_train_log)
y_val_pred = pipe_poly.predict(X_val_final)
rmse_val = np.sqrt(mean_squared_error(y_val_log, y_val_pred))
r2_val   = r2_score(y_val_log, y_val_pred)
print(f"Val  RMSE: {rmse_val:.3f}   R²: {r2_val:.3f}")
# Out:
# Poly-Ridge (deg=2)  CV-RMSE(log£):  0.591 ± 0.002
# Val  RMSE: 0.590   R²: 0.526

# %%
sns.scatterplot(x=y_val_pred, y=y_val_log - y_val_pred, alpha=.3)
plt.axhline(0, ls='--', c='r'); plt.xlabel("Fitted log£"); plt.ylabel("Residual"); 
plt.title("Poly-Ridge residuals – look for funnel / curvature"); plt.show()

# %%
pf_names = pipe_poly.named_steps["poly"].get_feature_names_out(base_numeric)
coef      = pipe_poly.named_steps["ridge"].coef_
coefs_df  = (pd.Series(coef, pf_names)
               .sort_values(key=np.abs, ascending=False)
               .head(15))         # top 15 magnitudes

sns.barplot(y=coefs_df.index, x=coefs_df.values, palette="deep")
plt.title("Largest poly-Ridge coefficients"); plt.xlabel("Weight (log£ units)"); plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

m, a = np.meshgrid(np.linspace(X_train_final.mileage.min(),  X_train_final.mileage.max(), 40),
                   np.linspace(X_train_final.vehicle_age.min(), X_train_final.vehicle_age.max(), 40))
grid = pd.DataFrame({"mileage":m.ravel(),
                     "vehicle_age":a.ravel(),
                     "mileage_per_year": np.median(X_train_final.mileage_per_year)})
z = pipe_poly.predict(grid).reshape(m.shape)

fig = plt.figure(figsize=(6,4)); ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(m, a, z, cmap="viridis", alpha=.8); ax.set_xlabel("mileage"); ax.set_ylabel("age"); 
ax.set_zlabel("log£"); plt.title("Poly-Ridge response surface"); plt.tight_layout(); plt.show()

# %%
# ── learning-surface for Polynomial + Ridge ──────────────────────────────────
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error

sns.set_style("whitegrid")

# --- grid to explore ---------------------------------------------------------
degrees = [1, 2, 3]                       # (1 = plain linear)
alphas  = np.logspace(-4, 1, 7)           # 0.0001 … 10
cv      = KFold(n_splits=5, shuffle=True, random_state=42)

results = []                              # collect tuples

for d in degrees:
    # pipeline: polynomial expansion  +  Ridge
    poly = PolynomialFeatures(degree=d, include_bias=False)
    for a in alphas:
        model = make_pipeline(poly, Ridge(alpha=a))
        # CV on training set – neg_MSE → RMSE
        rmse = np.sqrt(-cross_val_score(
            model,
            X_train_scaled[poly_features],
            y_train_log,
            scoring="neg_mean_squared_error",
            cv=cv,
            n_jobs=-1
        ).mean())
        results.append((d, a, rmse))

# tidy frame → easier plotting
surf = pd.DataFrame(results, columns=["degree", "alpha", "RMSE"])
surf["log10_alpha"] = np.log10(surf["alpha"])

# --- heat-map ----------------------------------------------------------------
plt.figure(figsize=(8, 5))
pivot = surf.pivot(index="degree", columns="log10_alpha", values="RMSE")
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="viridis_r",
            cbar_kws={"label":"CV-RMSE (log £)"})
plt.xlabel(r"log$_{10}(\alpha)$"); plt.ylabel("Polynomial degree")
plt.title("Cross-validated RMSE surface\nPolynomialFeatures + Ridge")
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ## 10. Clustering for Featuring
